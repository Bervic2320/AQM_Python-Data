# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from statsmodels import regression
import statsmodels.api as sm
import xlsxwriter
import seaborn as sns
from scipy.stats import shapiro
from statsmodels.tsa.vector_ar.vecm import coint_johansen
import scipy.stats as stats

# %%
import pandas as pd
import sqlite3

# Read the Excel file into a DataFrame
database = pd.read_excel("Daily_Currency_Prices.xlsx", index_col=0, skiprows=0)

# Establish a connection to the SQL database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Create a new table in the database and insert the DataFrame data into it
database.to_sql("Daily_Currency_Prices", connection, if_exists="replace")

# Close the database connection
connection.close()
database = pd.read_excel("Daily_Currency_Prices.xlsx",index_col=0,skiprows=0)

# %%
import sqlite3

# Establish a connection to the SQL database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Query to retrieve data from the database
query = "SELECT * FROM Daily_Currency_Prices"

# Read the SQL query into a DataFrame, setting the first column as dates and excluding it from columns
data = pd.read_sql_query(query, connection, parse_dates=['Date'], index_col='Date')



# Close the database connection
connection.close()

# %%
data.tail(10)
# Out:
#                  JPY     AUD     NZD     EUR     GBP       CAD       CHF  \
# Date
# 2023-04-17  0.007437  0.6700  0.6180  1.0926  1.2374  0.746714  1.112966
# 2023-04-18  0.007458  0.6722  0.6207  1.0971  1.2424  0.746993  1.116071
# 2023-04-19  0.007424  0.6713  0.6198  1.0954  1.2438  0.742942  1.114330
# 2023-04-20  0.007450  0.6740  0.6170  1.0967  1.2443  0.742170  1.120951
# 2023-04-21  0.007454  0.6690  0.6133  1.0987  1.2430  0.738607  1.120323
# 2023-04-24  0.007450  0.6696  0.6166  1.1041  1.2482  0.738607  1.127015
# 2023-04-25  0.007479  0.6625  0.6136  1.0972  1.2408  0.733945  1.121453
# 2023-04-26  0.007482  0.6598  0.6116  1.1040  1.2467  0.733407  1.122209
# 2023-04-27  0.007466  0.6629  0.6147  1.1027  1.2487  0.735781  1.118443
# 2023-04-28  0.007338  0.6607  0.6183  1.1020  1.2572  0.738007  1.118443
#
#                  TWD       CNY       INR  ...       HKD       PHP       SGD  \
# Date                                      ...
# 2023-04-17  0.032749  0.145378  0.012198  ...  0.127402  0.017883  0.749625
# 2023-04-18  0.032804  0.145444  0.012183  ...  0.127390  0.017809  0.750469
# 2023-04-19  0.032704  0.145243  0.012156  ...  0.127395  0.017730  0.749457
# 2023-04-20  0.032770  0.145507  0.012177  ...  0.127395  0.017895  0.750751
# 2023-04-21  0.032653  0.145096  0.012191  ...  0.127429  0.017895  0.749457
# 2023-04-24  0.032629  0.145016  0.012203  ...  0.127403  0.017969  0.749963
# 2023-04-25  0.032565  0.144252  0.012200  ...  0.127395  0.018012  0.747049
# 2023-04-26  0.032553  0.144381  0.012234  ...  0.127398  0.017966  0.748839
# 2023-04-27  0.032575  0.144467  0.012241  ...  0.127397  0.017950  0.749400
# 2023-04-28  0.032533  0.144697  0.012237  ...  0.127397  0.018028  0.749288
#
#                  THB       KRW       IDR       MYR       VND       TRY  \
# Date
# 2023-04-17  0.028994  0.000758  0.000068  0.226296  0.000043  0.051583
# 2023-04-18  0.029172  0.000758  0.000067  0.225632  0.000043  0.051584
#
#                  KHR
# Date
# 2013-01-01  0.000250
# 2013-01-02  0.000250
# 2013-01-03  0.000250
# 2013-01-04  0.000250
# 2013-01-07  0.000250
# ...              ...
# 2023-04-24  0.000245
# 2023-04-25  0.000245
# 2023-04-26  0.000244
# 2023-04-27  0.000244
# 2023-04-28  0.000243
#
# [2694 rows x 21 columns]

# %%
# Plot and save individual time series
for col in df_data.iteritems():
    print('plotting '+col[0])
    
    # create a new figure and axis
    fig, ax = plt.subplots()
    
    # extract the column data and plot it
    indicator = df_data[col[0]]
    ax.plot(indicator, alpha=0.9, color='#009ACD')
    
    # add x and y axis labels and a title
    ax.set_xlabel('Date')
    ax.set_ylabel(col[0])
    ax.set_title('Historic Prices: ' + col[0])
    
    # save the plot to a file and close the figure
    plt.savefig('Historic_price_'+col[0]+'.png')
    plt.close()
# Out:
# plotting JPY
# plotting AUD
# plotting NZD
# plotting EUR
# plotting GBP
# plotting CAD
# plotting CHF
# plotting TWD
# plotting CNY
# plotting INR
# plotting RUB
# plotting HKD
# plotting PHP
# plotting SGD
# plotting THB
# plotting KRW
# plotting IDR
# plotting MYR
# plotting VND
# plotting TRY
# plotting KHR

# %%
## Data on the 16th and 17th April 2014 was considered an outlier and an adjustment was made. Instead of making values=0,
#the average between the two values surrounding these days (15-04-2014 and 18-04-2014) was put instead of the original values

print('Before Adjustment',df_data['KHR'][336:338])
data['KHR'][336:338] = 0.000253
print('-------------')
print('After Adjustment',df_data['KHR'][336:338])
# Out:
# Before Adjustment Date
# 2014-04-16    0.000259
# 2014-04-17    0.000258
# Name: KHR, dtype: float64
# -------------
# After Adjustment Date
# 2014-04-16    0.000253
# 2014-04-17    0.000253
# Name: KHR, dtype: float64

# %%
# plot one series
plt.figure(figsize=(10, 6))
plt.plot(df_data['KHR'],color='#009ACD')
plt.savefig('plot_normalized.png')
plt.show()

# %%
################################################ RETURN CALCULATION ########################################################

returns = {}
for col in df_data.columns:
    log_returns = np.log(df_data[col] / df_data[col].shift(1)).dropna()
    returns[col] = log_returns
##########################################################################################3
returns_df = pd.DataFrame(returns)
correlation_matrix = returns_df.corr()

plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=1.5)
plt.title("Correlation Heatmap of Returns")
plt.savefig("correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import pandas as pd

# Create a DataFrame from the returns dictionary
returns_df = pd.DataFrame(returns)

# Calculate the correlation coefficients
correlation_matrix = returns_df.corr()

# Display the correlation coefficients
print(correlation_matrix)

df_correlation=pd.DataFrame(correlation_matrix)
df_correlation.to_excel('Correlation Matrix.xlsx', index=False)
# Out:
#           JPY       AUD       NZD       EUR       GBP       CAD       CHF  \
# JPY  1.000000  0.261353  0.315451  0.396237  0.257250  0.139041  0.432370
# AUD  0.261353  1.000000  0.800410  0.503640  0.531277  0.662600  0.353361
# NZD  0.315451  0.800410  1.000000  0.513849  0.509455  0.594621  0.386105
# EUR  0.396237  0.503640  0.513849  1.000000  0.590597  0.420318  0.624244
# GBP  0.257250  0.531277  0.509455  0.590597  1.000000  0.455058  0.399180
# NZD  0.463451  0.528038  0.163991  0.204240  0.019138  0.226756  0.009652
# EUR  0.373099  0.415654  0.090149  0.090909  0.012412  0.173946  0.004641
# GBP  0.345274  0.407829  0.119279  0.137126  0.006479  0.144116 -0.001429
# CAD  0.390315  0.498179  0.128845  0.160562 -0.001388  0.226334 -0.026585
# CHF  0.268717  0.275193  0.078141  0.094101  0.006290  0.074867 -0.008540
# TWD  0.466697  0.684713  0.201068  0.327387  0.043673  0.202259  0.000398
# CNY  0.396882  0.393138  0.247080  0.281148  0.105784  0.115558 -0.001067
# INR  0.329387  0.378834  0.254896  0.271882  0.014823  0.199612  0.019894
# RUB  0.176702  0.199557  0.081992  0.117279 -0.003106  0.164824  0.004063
# HKD  0.120878  0.161027  0.093126  0.117967  0.034573  0.047132  0.038717
# PHP  0.376129  0.451060  0.229090  0.308433  0.056060  0.167296 -0.002388
# SGD  0.568525  0.696655  0.232319  0.335246  0.046831  0.255991  0.010925
# THB  1.000000  0.537635  0.219929  0.288203  0.052453  0.179981  0.003143
# KRW  0.537635  1.000000  0.230613  0.318776  0.031831  0.228162 -0.005784
# IDR  0.219929  0.230613  1.000000  0.483556  0.113031  0.092991 -0.003198
# MYR  0.288203  0.318776  0.483556  1.000000  0.090836  0.079157 -0.010810
# VND  0.052453  0.031831  0.113031  0.090836  1.000000  0.046387  0.005010
# TRY  0.179981  0.228162  0.092991  0.079157  0.046387  1.000000  0.021542
# KHR  0.003143 -0.005784 -0.003198 -0.010810  0.005010  0.021542  1.000000
#
# [21 rows x 21 columns]

# %%
import pandas as pd
import sqlite3

# Read the Excel file into a DataFrame
database = pd.read_excel("Correlation Matrix.xlsx", index_col=0, skiprows=0)

# Establish a connection to the SQL database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Create a new table in the database and insert the DataFrame data into it
database.to_sql("Correlation Matrix", connection, if_exists="replace")

# Close the database connection
connection.close()
database = pd.read_excel("Correlation Matrix.xlsx",index_col=0,skiprows=0)

# %%
for col, returns_series in returns.items():
    std_dev = returns_series.std()*100
    print(f"Standard Deviation of {col}: {std_dev}")
# Out:
# Standard Deviation of JPY: 0.5751617000661801
# Standard Deviation of AUD: 0.6379608996249542
# Standard Deviation of NZD: 0.6575732472734734
# Standard Deviation of EUR: 0.4951241491340232
# Standard Deviation of GBP: 0.5867744245076816
# Standard Deviation of CAD: 0.46637472203128794
# Standard Deviation of CHF: 0.5965553569438323
# Standard Deviation of TWD: 0.29054063460862034
# Standard Deviation of CNY: 0.23577651192003404
# Standard Deviation of INR: 0.3994093353608701
# Standard Deviation of RUB: 1.4947767939490015
# Standard Deviation of HKD: 0.036357731178894834
# Standard Deviation of PHP: 0.3156227997880384
# Standard Deviation of SGD: 0.30306993842584884
# Standard Deviation of THB: 0.3390080299319326
# Standard Deviation of KRW: 0.5193025127572496
# Standard Deviation of IDR: 0.3921792558989963
# Standard Deviation of MYR: 0.38415150642679685
# Standard Deviation of VND: 0.13294356488911258
# Standard Deviation of TRY: 1.1015859416565514
# Standard Deviation of KHR: 0.3705836326381914

# %%
################################################# QQ PLOTS (FOR RETURNS) ################################################################
for col, ret in returns.items():
    sm.qqplot(ret, line='s')
    plt.title(col + ' QQ Plot')
    plt.savefig(col + '_returns_qqplot.png')
    plt.close()
    plt.show()

# %%
################################################ HISTOGRAM (FOR RETURNS) #####################################################

for col, ret in returns.items():
    plt.hist(ret, bins=30,color="#6C9AEC")
    plt.title(col + ' Returns Histogram')
    plt.xlabel('Returns')
    plt.ylabel('Frequency')
    plt.savefig(col + '_returns_hist.png')
    plt.close()
    #plt.show()

# %%
############################################ BOXPLOTS (RETURNS) ###########################################################

#Create data frame returns
df_returns=pd.DataFrame(returns)

# Make boxplot for each column of the data frame
for col in df_returns.columns:
    sns.boxplot(data=df_returns[col], color='#6C9AEC')
    plt.title(col)
    plt.savefig(col + '_boxplot.png')
    plt.close()
    #plt.show()

# %%
# Shapiro Wilk Test for each currency return
for col, ret in returns.items():
    stat, p = shapiro(ret)
    print('Shapiro-Wilk normality test for ' + col + ' returns:')
    print('Statistics=%.3f, p-value=%.7f' % (stat, p))
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
# Shapiro-Wilk normality test for JPY returns:
# Statistics=0.938, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for AUD returns:
# Statistics=0.984, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for NZD returns:
# Statistics=0.991, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for EUR returns:
# Statistics=0.981, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for GBP returns:
# Statistics=0.927, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for CAD returns:
# Statistics=0.989, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for CHF returns:
# Statistics=0.740, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for TWD returns:
# Statistics=0.961, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for CNY returns:
# Statistics=0.899, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for INR returns:
# Statistics=0.918, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for RUB returns:
# Statistics=0.759, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for HKD returns:
# Statistics=0.771, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for PHP returns:
# Statistics=0.981, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for SGD returns:
# Statistics=0.980, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for THB returns:
# Statistics=0.977, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for KRW returns:
# Statistics=0.986, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for IDR returns:
# Statistics=0.844, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for MYR returns:
# Statistics=0.903, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for VND returns:
# Statistics=0.745, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for TRY returns:
# Statistics=0.734, p-value=0.0000000
# Sample does not look Gaussian (reject H0)
# Shapiro-Wilk normality test for KHR returns:
# Statistics=0.830, p-value=0.0000000
# Sample does not look Gaussian (reject H0)

# %%
#   From the shapiro test we can conclude that the returns are not normally distributed

# %%
############################################# STATIONARITY TEST ###########################################################

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Testing stationarity in level
for column in df_data.columns:
    print("Column:", column)
    for lag in range(1, 3):
        print("Number of lags used:", lag)
        adf_level = adfuller(df_data[column], maxlag=lag, regression='n', autolag=None)
        adf_level_statistic = adf_level[0]
        adf_level_pvalue = adf_level[1]
        print("ADF Test Statistic (Level):", adf_level_statistic)
        print("p-value (Level):", adf_level_pvalue)
        print()

# Testing stationarity in first difference
for column in df_data.columns:
    print("Column:", column)
    for lag in range(1, 3):
        print("Number of lags used:", lag)
        df_diff = df_data[column].diff().dropna()  # Compute the first difference
        adf_diff = adfuller(df_diff, maxlag=lag, regression='n', autolag=None)
        adf_diff_statistic = adf_diff[0]
        adf_diff_pvalue = adf_diff[1]
        print("ADF Test Statistic (First Difference):", adf_diff_statistic)
        print("p-value (First Difference):", adf_diff_pvalue)
        print()
# Out:
# Column: JPY
# Number of lags used: 1
# ADF Test Statistic (Level): -1.7577678995526842
# p-value (Level): 0.07479789922304135
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.7514745971775059
# p-value (Level): 0.07580204621097408
#
# Column: AUD
# Number of lags used: 1
# ADF Test Statistic (Level): -1.9205170548688035
# p-value (Level): 0.0522991674949703
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.9071954053914606
# p-value (Level): 0.05390382501910354
#
# Column: NZD
# Number of lags used: 1
# ADF Test Statistic (Level): -1.115780787638335
# p-value (Level): 0.2400141586150915
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.0953134135725069
# p-value (Level): 0.24749520272129533
#
# Column: EUR
# Number of lags used: 1
# ADF Test Statistic (Level): -0.9015019267714878
# p-value (Level): 0.3282229587167702
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.845657148353843
# p-value (Level): 0.35140841335259254
#
# Column: GBP
# Number of lags used: 1
# ADF Test Statistic (Level): -1.0609464511543705
# p-value (Level): 0.260351612840959
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.0177102968107583
# p-value (Level): 0.2810300141491719
#
# Column: CAD
# Number of lags used: 1
# ADF Test Statistic (Level): -1.7325907674014056
# p-value (Level): 0.07887902698611843
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.7345077745199224
# p-value (Level): 0.07856225996749766
#
# Column: CHF
# Number of lags used: 1
# ADF Test Statistic (Level): -0.06642894534394096
# p-value (Level): 0.6617458319698932
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.019169088311221442
# p-value (Level): 0.6778661176739762
#
# Column: TWD
# Number of lags used: 1
# ADF Test Statistic (Level): -0.49027124557357626
# p-value (Level): 0.500118516197144
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.507819463549493
# p-value (Level): 0.49290720528686977
#
# Column: CNY
# Number of lags used: 1
# ADF Test Statistic (Level): -0.9260160120813853
# p-value (Level): 0.318132937306174
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.9290046482823665
# p-value (Level): 0.3169070809314297
#
# Column: INR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.138049980749455
# p-value (Level): 0.03119382044361503
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.3214672028306755
# p-value (Level): 0.019509600771947674
#
# Column: RUB
# Number of lags used: 1
# ADF Test Statistic (Level): -2.410480721818181
# p-value (Level): 0.015367853415558297
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.3969293826284845
# p-value (Level): 0.015943636023447262
#
# Column: HKD
# Number of lags used: 1
# ADF Test Statistic (Level): -0.6881941351475499
# p-value (Level): 0.41758354567221423
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.6878381193758198
# p-value (Level): 0.4177334969080182
#
# Column: PHP
# Number of lags used: 1
# ADF Test Statistic (Level): -2.1122574077174883
# p-value (Level): 0.03324047107864089
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.174057085837375
# p-value (Level): 0.02851670207365089
#
# Column: SGD
# Number of lags used: 1
# ADF Test Statistic (Level): -0.725543992453378
# p-value (Level): 0.40184669690433195
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.7064485315516098
# p-value (Level): 0.40989312495952307
#
# Column: THB
# Number of lags used: 1
# ADF Test Statistic (Level): -0.743357603471297
# p-value (Level): 0.39434175512266145
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.743870716093644
# p-value (Level): 0.3941256263739368
#
# Column: KRW
# Number of lags used: 1
# ADF Test Statistic (Level): -0.9671265863564349
# p-value (Level): 0.30136115830584687
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.9667197107489586
# p-value (Level): 0.3015261361439082
#
# Column: IDR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.4394401767413876
# p-value (Level): 0.014198433684027883
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.303073199393367
# p-value (Level): 0.020477738152248126
#
# Column: MYR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.1527340379203856
# p-value (Level): 0.030077272834721506
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.0948524201721748
# p-value (Level): 0.034684981832390535
#
# Column: VND
# Number of lags used: 1
# ADF Test Statistic (Level): -1.9675182042136223
# p-value (Level): 0.04694770851015784
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.9472631186283107
# p-value (Level): 0.04919567584252681
#
# Column: TRY
# Number of lags used: 1
# ADF Test Statistic (Level): -4.4418675677971375
# p-value (Level): 1.2075465024772176e-05
#
# Number of lags used: 2
# ADF Test Statistic (Level): -4.4746359127716175
# p-value (Level): 1.051534429231028e-05
#
# Column: KHR
# Number of lags used: 1
# ADF Test Statistic (Level): -0.27403457856744284
# p-value (Level): 0.586045887290706
#
# Number of lags used: 2
# ADF Test Statistic (Level): -0.2991674165878534
# p-value (Level): 0.5763867418587348
#
# Column: JPY
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.51433127206679
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.39185307379098
# p-value (First Difference): 0.0
#
# Column: AUD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.23499309560524
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.07985741706225
# p-value (First Difference): 0.0
#
# Column: NZD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.68453307392698
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.179997213189466
# p-value (First Difference): 0.0
#
# Column: EUR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.858263380111545
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.454482152943566
# p-value (First Difference): 0.0
#
# Column: GBP
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.181046773783535
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -29.918732722588043
# p-value (First Difference): 0.0
#
# Column: CAD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.54435963773318
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -29.959356598194205
# p-value (First Difference): 0.0
#
# Column: CHF
# Number of lags used: 1
# ADF Test Statistic (First Difference): -38.57411442067421
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.7068926053151
# p-value (First Difference): 0.0
#
# Column: TWD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -38.808517019972044
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -32.118220460132704
# p-value (First Difference): 0.0
#
# Column: CNY
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.756411650024404
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -28.924597056488253
# p-value (First Difference): 0.0
#
# Column: INR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -40.636790133571935
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -33.06376196949105
# p-value (First Difference): 0.0
#
# Column: RUB
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.13774268927791
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -29.590962176416518
# p-value (First Difference): 0.0
#
# Column: HKD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.85127503327605
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -31.34368431667034
# p-value (First Difference): 0.0
#
# Column: PHP
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.58273089434273
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -31.076542420273267
# p-value (First Difference): 0.0
#
# Column: SGD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -38.01951382778714
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.38130250415331
# p-value (First Difference): 0.0
#
# Column: THB
# Number of lags used: 1
# ADF Test Statistic (First Difference): -35.313890024434826
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -27.898325095427086
# p-value (First Difference): 0.0
#
# Column: KRW
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.37267093326957
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.534965764938466
# p-value (First Difference): 0.0
#
# Column: IDR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -31.748811460372117
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -26.813804277759754
# p-value (First Difference): 0.0
#
# Column: MYR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -34.02695748774383
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -28.752388740767415
# p-value (First Difference): 0.0
#
# Column: VND
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.51217424767276
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -27.166604500045082
# p-value (First Difference): 0.0
#
# Column: TRY
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.665397908808856
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.915497920066816
# p-value (First Difference): 0.0
#
# Column: KHR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -50.685724275025954
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -42.859992207147
# p-value (First Difference): 0.0

# %%
###### AQM METHOD ######
import numpy as np
from statsmodels.tsa.stattools import adfuller

var_list = df_data.columns

for lags in range(1, 3):
    print('Number of lags used:', lags)
    print('ADF P-Val for Prices (Level)')
    for i in var_list:
        adf_library = adfuller(df_data[i], maxlag=lags, regression='n', autolag=None)
        adf_library_d = adfuller(np.diff(df_data[i]), maxlag=lags, regression='n', autolag=None)

        print(i, ':', "%.12f" % adf_library[1])
    print('____________________________________________', '\n')
# Out:
# Number of lags used: 1
# ADF P-Val for Prices (Level)
# JPY : 0.074797899223
# AUD : 0.052299167495
# NZD : 0.240014158615
# EUR : 0.328222958717
# GBP : 0.260351612841
# CAD : 0.078879026986
# CHF : 0.661745831970
# TWD : 0.500118516197
# CNY : 0.318132937306
# INR : 0.031193820444
# RUB : 0.015367853416
# HKD : 0.417583545672
# PHP : 0.033240471079
# SGD : 0.401846696904
# THB : 0.394341755123
# KRW : 0.301361158306
# IDR : 0.014198433684
# MYR : 0.030077272835
# VND : 0.046947708510
# TRY : 0.000012075465
# KHR : 0.586045887291
# ____________________________________________
#
# Number of lags used: 2
# ADF P-Val for Prices (Level)
# JPY : 0.075802046211
# AUD : 0.053903825019
# NZD : 0.247495202721
# EUR : 0.351408413353
# GBP : 0.281030014149
# CAD : 0.078562259967
# CHF : 0.677866117674
# TWD : 0.492907205287
# CNY : 0.316907080931
# INR : 0.019509600772
# RUB : 0.015943636023
# HKD : 0.417733496908
# PHP : 0.028516702074
# SGD : 0.409893124960
# THB : 0.394125626374
# KRW : 0.301526136144
# IDR : 0.020477738152
# MYR : 0.034684981832
# VND : 0.049195675843
# TRY : 0.000010515344
# KHR : 0.576386741859
# ____________________________________________

# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller
import sqlite3

# Establish a connection to the SQLite database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# Drop the existing table if it exists
cursor.execute("DROP TABLE IF EXISTS adf_results")

# Create a new table to store the results
cursor.execute('''CREATE TABLE adf_results (
                    Currency_Asset TEXT,
                    lags INTEGER,
                    p_value REAL
                )''')

var_list = df_data.columns

for lags in range(1, 3):
    print('Number of lags used:', lags)
    print('ADF P-Val for Prices (Level)')
    for i in var_list:
        adf_library = adfuller(df_data[i], maxlag=lags, regression='n', autolag=None)
        adf_library_d = adfuller(np.diff(df_data[i]), maxlag=lags, regression='n', autolag=None)

        print(i, ':', "%.12f" % adf_library[1])

        # Insert the result into the database
        sql = "INSERT INTO adf_results (Currency_Asset, lags, p_value) VALUES (?, ?, ?)"
        values = (i, lags, adf_library[1])
        cursor.execute(sql, values)

    print('____________________________________________', '\n')

# Commit the changes to the database and close the connection
connection.commit()
cursor.close()
connection.close()
# Out:
# Number of lags used: 1
# ADF P-Val for Prices (Level)
# JPY : 0.074797899223
# AUD : 0.052299167495
# NZD : 0.240014158615
# EUR : 0.328222958717
# GBP : 0.260351612841
# CAD : 0.078879026986
# CHF : 0.661745831970
# TWD : 0.500118516197
# CNY : 0.318132937306
# INR : 0.031193820444
# RUB : 0.015367853416
# HKD : 0.417583545672
# PHP : 0.033240471079
# SGD : 0.401846696904
# THB : 0.394341755123
# KRW : 0.301361158306
# IDR : 0.014198433684
# MYR : 0.030077272835
# VND : 0.046947708510
# TRY : 0.000012075465
# KHR : 0.586045887291
# ____________________________________________
#
# Number of lags used: 2
# ADF P-Val for Prices (Level)
# JPY : 0.075802046211
# AUD : 0.053903825019
# NZD : 0.247495202721
# EUR : 0.351408413353
# GBP : 0.281030014149
# CAD : 0.078562259967
# CHF : 0.677866117674
# TWD : 0.492907205287
# CNY : 0.316907080931
# INR : 0.019509600772
# RUB : 0.015943636023
# HKD : 0.417733496908
# PHP : 0.028516702074
# SGD : 0.409893124960
# THB : 0.394125626374
# KRW : 0.301526136144
# IDR : 0.020477738152
# MYR : 0.034684981832
# VND : 0.049195675843
# TRY : 0.000010515344
# KHR : 0.576386741859
# ____________________________________________

# %% [markdown]
# The results indicate some currencies are stationary and some are not

# %%
################################################## DATA TRANSFORMATION ###################################################
#### List of non-stationary currencies
non_stationary_currencies = ['NZD', 'EUR', 'GBP', 'CHF', 'TWD', 'CNY', 'HKD', 'SGD', 'THB', 'KRW', 'KHR']

# Create a copy of df_data
df_data_copy = df_data.copy()

# Iterate over the non-stationary currencies
for currency in non_stationary_currencies:
    # Perform the first difference on the copy
    df_data_copy[f"{currency}_diff"] = df_data_copy[currency].diff()
    
# Drop the rows with NaN values resulting from differencing in the copy
df_data_copy.dropna(inplace=True)

df_data_copy
# Out:
#                  JPY     AUD     NZD     EUR     GBP       CAD       CHF  \
# Date
# 2013-01-02  0.011450  1.0503  0.8340  1.3184  1.6255  1.015435  1.089799
# 2013-01-03  0.011464  1.0464  0.8278  1.3046  1.6106  1.012453  1.079331
# 2013-01-04  0.011348  1.0478  0.8313  1.3067  1.6071  1.013171  1.082017
# 2013-01-07  0.011393  1.0502  0.8369  1.3115  1.6112  1.014713  1.085776
# 2013-01-08  0.011490  1.0501  0.8362  1.3080  1.6054  1.013788  1.082251
# ...              ...     ...     ...     ...     ...       ...       ...
# 2023-04-24  0.007450  0.6696  0.6166  1.1041  1.2482  0.738607  1.127015
# 2023-04-25  0.007479  0.6625  0.6136  1.0972  1.2408  0.733945  1.121453
# 2023-04-26  0.007482  0.6598  0.6116  1.1040  1.2467  0.733407  1.122209
# 2023-04-27  0.007466  0.6629  0.6147  1.1027  1.2487  0.735781  1.118443
# 2023-04-28  0.007338  0.6607  0.6183  1.1020  1.2572  0.738007  1.118443
#
#                  TWD       CNY       INR  ...  EUR_diff  GBP_diff  CHF_diff  \
# Date                                      ...
# 2013-01-02  0.034489  0.160511  0.018440  ...   -0.0020    0.0012 -0.002381
# 2013-01-03  0.034513  0.160511  0.018352  ...   -0.0138   -0.0149 -0.010469
# 2013-01-04  0.034468  0.160506  0.018205  ...    0.0021   -0.0035  0.002686
# 2013-01-07  0.034483  0.160529  0.018113  ...    0.0048    0.0041  0.003759
# 2013-01-08  0.034417  0.160671  0.018198  ...   -0.0035   -0.0058 -0.003525
# ...              ...       ...       ...  ...       ...       ...       ...
# 2023-04-24  0.032629  0.145016  0.012203  ...    0.0054    0.0052  0.006692
# 2023-04-25  0.032565  0.144252  0.012200  ...   -0.0069   -0.0074 -0.005561
# 2023-04-26  0.032553  0.144381  0.012234  ...    0.0068    0.0059  0.000755
# 2023-04-27  0.032575  0.144467  0.012241  ...   -0.0013    0.0020 -0.003765
# 2023-04-28  0.032533  0.144697  0.012237  ...   -0.0007    0.0085  0.000000
#
#             TWD_diff  CNY_diff  HKD_diff  SGD_diff  THB_diff      KRW_diff  \
# Date
# 2013-01-02  0.000059  0.000000 -0.000005  0.000671  0.000237 -5.307184e-08
# 2013-01-03  0.000024  0.000000  0.000000 -0.003745  0.000022  3.096702e-07
# 2013-01-04 -0.000044 -0.000005  0.000010 -0.000665 -0.000130  7.174480e-07
# 2013-01-07  0.000014  0.000023 -0.000013 -0.001393  0.000022 -7.262985e-07
# 2013-01-08 -0.000065  0.000142 -0.000010 -0.000132  0.000043 -8.753809e-07
# ...              ...       ...       ...       ...       ...           ...
# 2023-04-24 -0.000025 -0.000080 -0.000026  0.000506  0.000008 -1.778269e-06
# 2023-04-25 -0.000064 -0.000764 -0.000008 -0.002913 -0.000051 -4.690082e-06
# 2023-04-26 -0.000012  0.000129  0.000003  0.001790  0.000221  1.605240e-06
# 2023-04-27  0.000022  0.000086 -0.000002  0.000561  0.000000 -6.473854e-07
# 2023-04-28 -0.000042  0.000230  0.000000 -0.000112  0.000017  7.758797e-07
#
#                 KHR_diff
# Date
# 2013-01-02  0.000000e+00
# 2013-01-03  0.000000e+00
# 2013-01-04  0.000000e+00
# 2013-01-07  0.000000e+00
# 2013-01-08  0.000000e+00
# ...                  ...
# 2023-04-24 -7.226483e-07
# 2023-04-25 -4.794091e-07
# 2023-04-26 -4.179468e-07
# 2023-04-27 -5.352657e-07
# 2023-04-28 -2.371432e-07
#
# [2693 rows x 32 columns]

# %%
# List of columns to drop
columns_to_drop = ['NZD', 'EUR', 'GBP', 'CHF', 'TWD', 'CNY', 'HKD', 'SGD', 'THB', 'KRW', 'KHR']

# Create a new DataFrame with the dropped columns
df_transformed = df_data_copy.drop(columns=columns_to_drop)

print(df_transformed)  # Print the new DataFrame

# Export the new DataFrame to Excel
df_transformed.to_excel('df_transformed.xlsx', index=False)
# Out:
#                  JPY     AUD       CAD       INR       RUB       PHP  \
# Date
# 2013-01-02  0.011450  1.0503  1.015435  0.018440  0.033157  0.024480
# 2013-01-03  0.011464  1.0464  1.012453  0.018352  0.033074  0.024570
# 2013-01-04  0.011348  1.0478  1.013171  0.018205  0.032979  0.024498
# 2013-01-07  0.011393  1.0502  1.014713  0.018113  0.032966  0.024456
# 2013-01-08  0.011490  1.0501  1.013788  0.018198  0.033006  0.024516
# ...              ...     ...       ...       ...       ...       ...
# 2023-04-24  0.007450  0.6696  0.738607  0.012203  0.012423  0.017969
# 2023-04-25  0.007479  0.6625  0.733945  0.012200  0.012392  0.018012
# 2023-04-26  0.007482  0.6598  0.733407  0.012234  0.012177  0.017966
# 2023-04-27  0.007466  0.6629  0.735781  0.012241  0.012256  0.017950
# 2023-04-28  0.007338  0.6607  0.738007  0.012237  0.012587  0.018028
#
#                  IDR       MYR       VND       TRY  ...  EUR_diff  GBP_diff  \
# Date                                                ...
# 2013-01-02  0.000104  0.329598  0.000048  0.562841  ...   -0.0020    0.0012
# 2013-01-03  0.000104  0.330033  0.000048  0.560538  ...   -0.0138   -0.0149
# 2013-01-04  0.000104  0.328181  0.000048  0.561861  ...    0.0021   -0.0035
# 2013-01-07  0.000104  0.328785  0.000048  0.562493  ...    0.0048    0.0041
# 2013-01-08  0.000104  0.328666  0.000048  0.562968  ...   -0.0035   -0.0058
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-04-24  0.000067  0.225479  0.000043  0.051517  ...    0.0054    0.0052
# 2023-04-25  0.000067  0.225073  0.000043  0.051481  ...   -0.0069   -0.0074
# 2023-04-26  0.000067  0.224467  0.000043  0.051554  ...    0.0068    0.0059
# 2023-04-27  0.000068  0.224215  0.000043  0.051456  ...   -0.0013    0.0020
# 2023-04-28  0.000068  0.224316  0.000043  0.051420  ...   -0.0007    0.0085
#
#             CHF_diff  TWD_diff  CNY_diff  HKD_diff  SGD_diff  THB_diff  \
# Date
# 2013-01-02 -0.002381  0.000059  0.000000 -0.000005  0.000671  0.000237
# 2013-01-03 -0.010469  0.000024  0.000000  0.000000 -0.003745  0.000022
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-04-24  0.000067  0.225479  0.000043  0.051517  ...    0.0054    0.0052
# 2023-04-25  0.000067  0.225073  0.000043  0.051481  ...   -0.0069   -0.0074
# 2023-04-26  0.000067  0.224467  0.000043  0.051554  ...    0.0068    0.0059
# 2023-04-27  0.000068  0.224215  0.000043  0.051456  ...   -0.0013    0.0020
# 2023-04-28  0.000068  0.224316  0.000043  0.051420  ...   -0.0007    0.0085
#
#             CHF_diff  TWD_diff  CNY_diff  HKD_diff  SGD_diff  THB_diff  \
# Date
# 2013-01-02 -0.002381  0.000059  0.000000 -0.000005  0.000671  0.000237
# 2013-01-03 -0.010469  0.000024  0.000000  0.000000 -0.003745  0.000022
# 2013-01-04  0.002686 -0.000044 -0.000005  0.000010 -0.000665 -0.000130
# 2013-01-07  0.003759  0.000014  0.000023 -0.000013 -0.001393  0.000022
# 2013-01-08 -0.003525 -0.000065  0.000142 -0.000010 -0.000132  0.000043
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  0.006692 -0.000025 -0.000080 -0.000026  0.000506  0.000008
# 2023-04-25 -0.005561 -0.000064 -0.000764 -0.000008 -0.002913 -0.000051
# 2023-04-26  0.000755 -0.000012  0.000129  0.000003  0.001790  0.000221
# 2023-04-27 -0.003765  0.000022  0.000086 -0.000002  0.000561  0.000000
# 2023-04-28  0.000000 -0.000042  0.000230  0.000000 -0.000112  0.000017
#
#                 KRW_diff      KHR_diff
# Date
# 2013-01-02 -5.307184e-08  0.000000e+00
# 2013-01-03  3.096702e-07  0.000000e+00
# 2013-01-04  7.174480e-07  0.000000e+00
# 2013-01-07 -7.262985e-07  0.000000e+00
# 2013-01-08 -8.753809e-07  0.000000e+00
# ...                  ...           ...
# 2023-04-24 -1.778269e-06 -7.226483e-07
# 2023-04-25 -4.690082e-06 -4.794091e-07
# 2023-04-26  1.605240e-06 -4.179468e-07
# 2023-04-27 -6.473854e-07 -5.352657e-07
# 2023-04-28  7.758797e-07 -2.371432e-07
#
# [2693 rows x 21 columns]

# %%
import pandas as pd
import sqlite3

# Read the Excel file into a DataFrame
database = pd.read_excel("df_transformed.xlsx", index_col=0, skiprows=0)

# Establish a connection to the SQL database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Create a new table in the database and insert the DataFrame data into it
database.to_sql("df_transformed", connection, if_exists="replace")

# Close the database connection
connection.close()
database = pd.read_excel("df_transformed.xlsx",index_col=0,skiprows=0)

# %%
#################### STATIONARITY TEST TO TRANSFORMED DATA ###############################################3
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Testing stationarity in level
for column in df_transformed.columns:
    print("Column:", column)
    for lag in range(1, 3):
        print("Number of lags used:", lag)
        adf_level = adfuller(df_transformed[column], maxlag=lag, regression='n', autolag=None)
        adf_level_statistic = adf_level[0]
        adf_level_pvalue = adf_level[1]
        print("ADF Test Statistic (Level):", adf_level_statistic)
        print("p-value (Level):", adf_level_pvalue)
        print()

# Testing stationarity in first difference
for column in df_transformed.columns:
    print("Column:", column)
    for lag in range(1, 3):
        print("Number of lags used:", lag)
        df_diff = df_transformed[column].diff().dropna()  # Compute the first difference
        adf_diff = adfuller(df_diff, maxlag=lag, regression='n', autolag=None)
        adf_diff_statistic = adf_diff[0]
        adf_diff_pvalue = adf_diff[1]
        print("ADF Test Statistic (First Difference):", adf_diff_statistic)
        print("p-value (First Difference):", adf_diff_pvalue)
        print()
# Out:
# Column: JPY
# Number of lags used: 1
# ADF Test Statistic (Level): -1.7640458162003594
# p-value (Level): 0.07380670950104778
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.7005370634455237
# p-value (Level): 0.08432540154303775
#
# Column: AUD
# Number of lags used: 1
# ADF Test Statistic (Level): -1.9002158974127141
# p-value (Level): 0.054760478474534885
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.9151763314309134
# p-value (Level): 0.052937718800694374
#
# Column: CAD
# Number of lags used: 1
# ADF Test Statistic (Level): -1.7134134964319205
# p-value (Level): 0.08210332393285075
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.7400321487614383
# p-value (Level): 0.07765499752346543
#
# Column: INR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.1003695009257
# p-value (Level): 0.03422145633007573
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.27040673769679
# p-value (Level): 0.022300358484357807
#
# Column: RUB
# Number of lags used: 1
# ADF Test Statistic (Level): -2.396668845550206
# p-value (Level): 0.015954889440710673
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.383397084979511
# p-value (Level): 0.016537457361871972
#
# Column: PHP
# Number of lags used: 1
# ADF Test Statistic (Level): -2.1475065266667475
# p-value (Level): 0.030470792594971246
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.1478888187004843
# p-value (Level): 0.030441866202324912
#
# Column: IDR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.44197606130347
# p-value (Level): 0.014099875133745164
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.29458795326299
# p-value (Level): 0.020938259907401436
#
# Column: MYR
# Number of lags used: 1
# ADF Test Statistic (Level): -2.1597627922291482
# p-value (Level): 0.029554996653316457
#
# Number of lags used: 2
# ADF Test Statistic (Level): -2.0431008743237955
# p-value (Level): 0.03929695277939607
#
# Column: VND
# Number of lags used: 1
# ADF Test Statistic (Level): -1.96787667978203
# p-value (Level): 0.046908701999540926
#
# Number of lags used: 2
# ADF Test Statistic (Level): -1.9350242022939255
# p-value (Level): 0.050596469665858915
#
# Column: TRY
# Number of lags used: 1
# ADF Test Statistic (Level): -4.407077121645919
# p-value (Level): 1.3976514066537854e-05
#
# Number of lags used: 2
# ADF Test Statistic (Level): -4.498843091009751
# p-value (Level): 9.490073392487465e-06
#
# Column: NZD_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -37.68453307392698
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -30.179997213189466
# p-value (Level): 0.0
#
# Column: EUR_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -36.858263380111545
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -30.454482152943566
# p-value (Level): 0.0
#
# Column: GBP_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -36.181046773783535
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -29.918732722588043
# p-value (Level): 0.0
#
# Column: CHF_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -38.57411442067421
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -30.7068926053151
# p-value (Level): 0.0
#
# Column: TWD_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -38.808517019972044
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -32.118220460132704
# p-value (Level): 0.0
#
# Column: CNY_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -36.756411650024404
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -28.924597056488253
# p-value (Level): 0.0
#
# Column: HKD_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -36.85127503327605
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -31.34368431667034
# p-value (Level): 0.0
#
# Column: SGD_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -38.01951382778714
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -30.38130250415331
# p-value (Level): 0.0
#
# Column: THB_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -35.313890024434826
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -27.898325095427086
# p-value (Level): 0.0
#
# Column: KRW_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -37.37267093326957
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -30.534965764938466
# p-value (Level): 0.0
#
# Column: KHR_diff
# Number of lags used: 1
# ADF Test Statistic (Level): -50.685724275025954
# p-value (Level): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (Level): -42.859992207147
# p-value (Level): 0.0
#
# Column: JPY
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.577498179235775
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.331409829282887
# p-value (First Difference): 0.0
#
# Column: AUD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.22694472063345
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.07945515774499
# p-value (First Difference): 0.0
#
# Column: CAD
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.53468845867747
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -29.95653863310619
# p-value (First Difference): 0.0
#
# Column: INR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -40.62941069655836
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -33.092582235096096
# p-value (First Difference): 0.0
#
# Column: RUB
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.11433941894832
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -29.582190961866534
# p-value (First Difference): 0.0
#
# Column: PHP
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.51489418838375
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -31.055523254488723
# p-value (First Difference): 0.0
#
# Column: IDR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -31.74520958430189
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -26.808935481646714
# p-value (First Difference): 0.0
#
# Column: MYR
# Number of lags used: 1
# ADF Test Statistic (First Difference): -33.94439618440562
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -28.756801017935178
# p-value (First Difference): 0.0
#
# Column: VND
# Number of lags used: 1
# ADF Test Statistic (First Difference): -37.505854269864074
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -27.160348143636156
# p-value (First Difference): 0.0
#
# Column: TRY
# Number of lags used: 1
# ADF Test Statistic (First Difference): -36.658362334450395
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -30.910878732788763
# p-value (First Difference): 0.0
#
# Column: NZD_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -65.08003695913776
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -53.190550553188814
# p-value (First Difference): 0.0
#
# Column: EUR_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -63.19192392498065
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -51.78687414954652
# p-value (First Difference): 0.0
#
# Column: GBP_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -62.43394018268605
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -51.13640407676566
# p-value (First Difference): 0.0
#
# Column: CHF_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -64.74675304163218
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -54.80263708123967
# p-value (First Difference): 0.0
#
# Column: TWD_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -63.902664578678355
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -53.92999454911582
# p-value (First Difference): 0.0
#
# Column: CNY_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -65.24883926910314
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -53.25883844429982
# p-value (First Difference): 0.0
#
# Column: HKD_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -61.7826623341103
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -52.003775482100956
# p-value (First Difference): 0.0
#
# Column: SGD_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -64.97865855462393
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -53.086397189042465
# p-value (First Difference): 0.0
#
# Column: THB_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -63.70334346910732
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -52.147448275141485
# p-value (First Difference): 0.0
#
# Column: KRW_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -64.24801666984983
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -51.51734706431736
# p-value (First Difference): 0.0
#
# Column: KHR_diff
# Number of lags used: 1
# ADF Test Statistic (First Difference): -71.76342740853497
# p-value (First Difference): 0.0
#
# Number of lags used: 2
# ADF Test Statistic (First Difference): -60.608361997350485
# p-value (First Difference): 0.0

# %%
###### AQM METHOD ######
import numpy as np
from statsmodels.tsa.stattools import adfuller

var_list = df_transformed.columns

for lags in range(1, 3):
    print('Number of lags used:', lags)
    print('ADF P-Val for Prices (Level)')
    for i in var_list:
        adf_library = adfuller(df_transformed[i], maxlag=lags, regression='n', autolag=None)
        adf_library_d = adfuller(np.diff(df_transformed[i]), maxlag=lags, regression='n', autolag=None)

        print(i, ':', "%.12f" % adf_library[1])
    print('____________________________________________', '\n')
# Out:
# Number of lags used: 1
# ADF P-Val for Prices (Level)
# JPY : 0.073806709501
# AUD : 0.054760478475
# CAD : 0.082103323933
# INR : 0.034221456330
# RUB : 0.015954889441
# PHP : 0.030470792595
# IDR : 0.014099875134
# MYR : 0.029554996653
# VND : 0.046908702000
# TRY : 0.000013976514
# NZD_diff : 0.000000000000
# EUR_diff : 0.000000000000
# GBP_diff : 0.000000000000
# CHF_diff : 0.000000000000
# TWD_diff : 0.000000000000
# CNY_diff : 0.000000000000
# HKD_diff : 0.000000000000
# SGD_diff : 0.000000000000
# THB_diff : 0.000000000000
# KRW_diff : 0.000000000000
# KHR_diff : 0.000000000000
# ____________________________________________
#
# Number of lags used: 2
# ADF P-Val for Prices (Level)
# JPY : 0.084325401543
# AUD : 0.052937718801
# CAD : 0.077654997523
# INR : 0.022300358484
# RUB : 0.016537457362
# PHP : 0.030441866202
# IDR : 0.020938259907
# MYR : 0.039296952779
# VND : 0.050596469666
# TRY : 0.000009490073
# NZD_diff : 0.000000000000
# EUR_diff : 0.000000000000
# GBP_diff : 0.000000000000
# CHF_diff : 0.000000000000
# TWD_diff : 0.000000000000
# CNY_diff : 0.000000000000
# HKD_diff : 0.000000000000
# SGD_diff : 0.000000000000
# THB_diff : 0.000000000000
# KRW_diff : 0.000000000000
# KHR_diff : 0.000000000000
# ____________________________________________

# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller
import sqlite3

# Establish a connection to the SQLite database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# Drop the existing table if it exists
cursor.execute("DROP TABLE IF EXISTS adf_results_stationary")

# Create a new table to store the results
cursor.execute('''CREATE TABLE adf_results_stationary (
                    Currency_Asset TEXT,
                    lags INTEGER,
                    p_value REAL
                )''')

var_list = df_data.columns

for lags in range(1, 3):
    print('Number of lags used:', lags)
    print('ADF P-Val for Prices (Level)')
    for i in var_list:
        adf_library = adfuller(df_data[i], maxlag=lags, regression='n', autolag=None)
        adf_library_d = adfuller(np.diff(df_data[i]), maxlag=lags, regression='n', autolag=None)

        print(i, ':', "%.12f" % adf_library[1])

        # Insert the result into the database
        sql = "INSERT INTO adf_results_stationary (Currency_Asset, lags, p_value) VALUES (?, ?, ?)"
        values = (i, lags, adf_library[1])
        cursor.execute(sql, values)

    print('____________________________________________', '\n')

# Commit the changes to the database and close the connection
connection.commit()
cursor.close()
connection.close()
# Out:
# Number of lags used: 1
# ADF P-Val for Prices (Level)
# JPY : 0.074797899223
# AUD : 0.052299167495
# NZD : 0.240014158615
# EUR : 0.328222958717
# GBP : 0.260351612841
# CAD : 0.078879026986
# CHF : 0.661745831970
# TWD : 0.500118516197
# CNY : 0.318132937306
# INR : 0.031193820444
# RUB : 0.015367853416
# HKD : 0.417583545672
# PHP : 0.033240471079
# SGD : 0.401846696904
# THB : 0.394341755123
# KRW : 0.301361158306
# IDR : 0.014198433684
# MYR : 0.030077272835
# VND : 0.046947708510
# TRY : 0.000012075465
# KHR : 0.586045887291
# ____________________________________________
#
# Number of lags used: 2
# ADF P-Val for Prices (Level)
# JPY : 0.075802046211
# AUD : 0.053903825019
# NZD : 0.247495202721
# EUR : 0.351408413353
# GBP : 0.281030014149
# CAD : 0.078562259967
# CHF : 0.677866117674
# TWD : 0.492907205287
# CNY : 0.316907080931
# INR : 0.019509600772
# RUB : 0.015943636023
# HKD : 0.417733496908
# PHP : 0.028516702074
# SGD : 0.409893124960
# THB : 0.394125626374
# KRW : 0.301526136144
# IDR : 0.020477738152
# MYR : 0.034684981832
# VND : 0.049195675843
# TRY : 0.000010515344
# KHR : 0.576386741859
# ____________________________________________

# %%
# After running the first difference we can conclude that  the variables are integrated in order (1)

# %%
##################################### COINTEGRATION TEST NON-TRANSFORMED ######################################

# %%
var_list = df_data.columns
var_list
# Out:
# Index(['JPY', 'AUD', 'NZD', 'EUR', 'GBP', 'CAD', 'CHF', 'TWD', 'CNY', 'INR',
#        'RUB', 'HKD', 'PHP', 'SGD', 'THB', 'KRW', 'IDR', 'MYR', 'VND', 'TRY',
#        'KHR'],
#       dtype='object')

# %%
####### AQM COINTEGRATION NON TRANSFORMED ############
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.vector_ar.vecm import coint_johansen

x_list = var_list
y_list = var_list
max_lags = 2
counter_total = 1
counter_lib_ECMLib = 1
counter_lib_ECMLib_n_Coded = 1

results = []  # List to store the results

results.append(['Asset', 'Test', 'ADF Lags', 'Cointegration Result', 'P-value', 'Cointegration Score', 'R-squared'])  # Header row

print('Number of identified cointegrations using the ECM Library by asset:')

for y_name in y_list:
    y = df_data[y_name]
    counter_lib_ECMLib_success_temp = 0
    counter_total_byasset = 0

    print('Asset:', y_name)

    for lags in range(0, max_lags+1, 1):  # Update the range to include max_lags
        for i in x_list:
            if not y_name == i:
                counter_total = counter_total + 1
                counter_total_byasset = counter_total_byasset + 1

                x_n = df_data[i]

                if y.shape > x_n.shape:
                    temp = y.drop(y.index[0])
                    y = temp
                elif y.shape < x_n.shape:
                    temp = x_n.drop(x_n.index[0])
                    d_i = temp
                if x_n.shape != y.shape:
                    print('Warning Data Problem: Y', y.shape, 'X:', x_n.shape)

                # Step 1: Stationarity Tests for the Residual between Y and other variables
                step1_myols = sm.OLS(y, x_n)
                step1_est_resid = step1_myols.fit().resid

                adf_library = sm.tsa.stattools.adfuller(step1_est_resid, maxlag=lags, regression='n', autolag=None)

                # ECM results
                ECM_results_lib = sm.tsa.stattools.coint(y, df_data[i], trend='c', maxlag=lags)

                if ECM_results_lib[1] < 0.1:  # Update the confidence level to 10% (0.1)
                    counter_lib_ECMLib = counter_lib_ECMLib + 1

                    OLS_results_lib = sm.OLS(y, x_n, hasconst=None).fit()
                    OLS_results_code = sm.OLS(y, x_n)

                    cointegration_result = 'Cointegration Identified'
                    p_value = ECM_results_lib[1]
                    cointegration_score = ECM_results_lib[0]
                    r_squared = OLS_results_lib.rsquared
                    counter_lib_ECMLib_success_temp = counter_lib_ECMLib_success_temp + 1

                else:
                    cointegration_result = 'No Cointegration'
                    p_value = '-'
                    cointegration_score = '-'
                    r_squared = '-'

                results.append([y_name, i, lags, cointegration_result, p_value, cointegration_score, r_squared])  # Add row to results list

                print('Test:', i, ', ADF Lags:', lags, ', Result:', cointegration_result)

    print('Total cointegration identified for', y_name, ':', counter_lib_ECMLib_success_temp, 'out of total',
          counter_total_byasset)

print('\n', 'total number of regressions conducted:', counter_total - 1)
print('total number of identified cointegrations using only ECM Library:', counter_lib_ECMLib - 1)
print('total number of identified cointegrations using both ECM Library and own code:', counter_lib_ECMLib_n_Coded - 1)

      # Export results to Excel
# Export results to Excel
df_results = pd.DataFrame(results[1:], columns=results[0])  # Create a DataFrame from the results list
df_results.to_excel('results_ECM.xlsx', index=False)  # Export the DataFrame to an Excel file
# Out:
# Number of identified cointegrations using the ECM Library by asset:
# Asset: JPY
# Test: AUD , ADF Lags: 0 , Result: No Cointegration
# Test: NZD , ADF Lags: 0 , Result: No Cointegration
# Test: EUR , ADF Lags: 0 , Result: No Cointegration
# Test: GBP , ADF Lags: 0 , Result: No Cointegration
# Test: CAD , ADF Lags: 0 , Result: No Cointegration
# Test: CHF , ADF Lags: 0 , Result: No Cointegration
# Test: TWD , ADF Lags: 0 , Result: No Cointegration
# Test: CNY , ADF Lags: 0 , Result: No Cointegration
# Test: INR , ADF Lags: 0 , Result: No Cointegration
# Test: RUB , ADF Lags: 0 , Result: No Cointegration
# Test: HKD , ADF Lags: 0 , Result: No Cointegration
# Test: PHP , ADF Lags: 0 , Result: No Cointegration
# Test: SGD , ADF Lags: 0 , Result: No Cointegration
# Test: THB , ADF Lags: 0 , Result: No Cointegration
# Test: KRW , ADF Lags: 0 , Result
, Result: Cointegration Identified
# Test: TRY , ADF Lags: 0 , Result: Cointegration Identified
# Test: JPY , ADF Lags: 1 , Result: Cointegration Identified
# Test: AUD , ADF Lags: 1 , Result: Cointegration Identified
# Test: NZD , ADF Lags: 1 , Result: Cointegration Identified
# Test: EUR , ADF Lags: 1 , Result: Cointegration Identified
# Test: GBP , ADF Lags: 1 , Result: Cointegration Identified
# Test: CAD , ADF Lags: 1 , Result: Cointegration Identified
# Test: CHF , ADF Lags: 1 , Result: Cointegration Identified
# Test: TWD , ADF Lags: 1 , Result: Cointegration Identified
# Test: CNY , ADF Lags: 1 , Result: Cointegration Identified
# Test: INR , ADF Lags: 1 , Result: Cointegration Identified
# Test: RUB , ADF Lags: 1 , Result: Cointegration Identified
# Test: HKD , ADF Lags: 1 , Result: Cointegration Identified
# Test: PHP , ADF Lags: 1 , Result: Cointegration Identified
# Test: SGD , ADF Lags: 1 , Result: Cointegration Identified
# Test: THB , ADF Lags: 1 , Result: Cointegration Identified
# Test: KRW , ADF Lags: 1 , Result: Cointegration Identified
# Test: IDR , ADF Lags: 1 , Result: Cointegration Identified
# Test: MYR , ADF Lags: 1 , Result: Cointegration Identified
# Test: VND , ADF Lags: 1 , Result: Cointegration Identified
# Test: TRY , ADF Lags: 1 , Result: Cointegration Identified
# Test: JPY , ADF Lags: 2 , Result: Cointegration Identified
# Test: AUD , ADF Lags: 2 , Result: Cointegration Identified
# Test: NZD , ADF Lags: 2 , Result: Cointegration Identified
# Test: EUR , ADF Lags: 2 , Result: Cointegration Identified
# Test: GBP , ADF Lags: 2 , Result: Cointegration Identified
# Test: CAD , ADF Lags: 2 , Result: Cointegration Identified
# Test: CHF , ADF Lags: 2 , Result: Cointegration Identified
# Test: TWD , ADF Lags: 2 , Result: Cointegration Identified
# Test: CNY , ADF Lags: 2 , Result: Cointegration Identified
# Test: INR , ADF Lags: 2 , Result: Cointegration Identified
# Test: RUB , ADF Lags: 2 , Result: Cointegration Identified
# Test: HKD , ADF Lags: 2 , Result: Cointegration Identified
# Test: PHP , ADF Lags: 2 , Result: Cointegration Identified
# Test: SGD , ADF Lags: 2 , Result: Cointegration Identified
# Test: THB , ADF Lags: 2 , Result: Cointegration Identified
# Test: KRW , ADF Lags: 2 , Result: Cointegration Identified
# Test: IDR , ADF Lags: 2 , Result: Cointegration Identified
# Test: MYR , ADF Lags: 2 , Result: Cointegration Identified
# Test: VND , ADF Lags: 2 , Result: Cointegration Identified
# Test: TRY , ADF Lags: 2 , Result: Cointegration Identified
# Total cointegration identified for KHR : 60 out of total 60
#
#  total number of regressions conducted: 1260
# total number of identified cointegrations using only ECM Library: 336
# total number of identified cointegrations using both ECM Library and own code: 0

# %%
import pandas as pd
import sqlite3
import statsmodels.api as sm
from statsmodels.tsa.vector_ar.vecm import coint_johansen

x_list = var_list
y_list = var_list
max_lags = 2
counter_total = 1
counter_lib_ECMLib = 1
counter_lib_ECMLib_n_Coded = 1

results = []  # List to store the results

results.append(['Asset', 'Test', 'ADF Lags', 'Cointegration_Result', 'P_value', 'Cointegration_Score', 'R_squared'])  # Header row

print('Number of identified cointegrations using the ECM Library by asset:')

for y_name in y_list:
    y = df_data[y_name]
    counter_lib_ECMLib_success_temp = 0
    counter_total_byasset = 0

    print('Asset:', y_name)

    for lags in range(0, max_lags + 1, 1):  # Update the range to include max_lags
        for i in x_list:
            if not y_name == i:
                counter_total = counter_total + 1
                counter_total_byasset = counter_total_byasset + 1

                x_n = df_data[i]

                if y.shape > x_n.shape:
                    temp = y.drop(y.index[0])
                    y = temp
                elif y.shape < x_n.shape:
                    temp = x_n.drop(x_n.index[0])
                    d_i = temp
                if x_n.shape != y.shape:
                    print('Warning Data Problem: Y', y.shape, 'X:', x_n.shape)

                # Step 1: Stationarity Tests for the Residual between Y and other variables
                step1_myols = sm.OLS(y, x_n)
                step1_est_resid = step1_myols.fit().resid

                adf_library = sm.tsa.stattools.adfuller(step1_est_resid, maxlag=lags, regression='n', autolag=None)

                # ECM results
                ECM_results_lib = sm.tsa.stattools.coint(y, df_data[i], trend='c', maxlag=lags)

                if ECM_results_lib[1] < 0.1:  # Update the confidence level to 10% (0.1)
                    counter_lib_ECMLib = counter_lib_ECMLib + 1

                    OLS_results_lib = sm.OLS(y, x_n, hasconst=None).fit()
                    OLS_results_code = sm.OLS(y, x_n)

                    cointegration_result = 'Cointegration_Identified'
                    p_value = ECM_results_lib[1]
                    cointegration_score = ECM_results_lib[0]
                    r_squared = OLS_results_lib.rsquared
                    counter_lib_ECMLib_success_temp = counter_lib_ECMLib_success_temp + 1

                else:
                    cointegration_result = 'No_Cointegration'
                    p_value = '-'
                    cointegration_score = '-'
                    r_squared = '-'

                results.append([y_name, i, lags, cointegration_result, p_value, cointegration_score, r_squared])  # Add row to results list

                print('Test:', i, ', ADF Lags:', lags, ', Result:', cointegration_result)

    print('Total cointegration identified for', y_name, ':', counter_lib_ECMLib_success_temp, 'out of total',
          counter_total_byasset)

print('\n', 'Total number of regressions conducted:', counter_total - 1)
print('Total number of identified cointegrations using only ECM Library:', counter_lib_ECMLib - 1)
print('Total number of identified cointegrations using both ECM Library and own code:', counter_lib_ECMLib_n_Coded - 1)

# Create a DataFrame from the results list
df_results = pd.DataFrame(results[1:], columns=results[0])

# Establish a connection to the SQL database
connection = sqlite3.connect("Currencies_Database_Test.db")

# Export the DataFrame to the 'Engle_Granger_Cointegration_Relationships' table in the database
df_results.to_sql('Engle_Granger_Cointegration_Relationships', connection, if_exists='replace', index=False)

# Close the database connection
connection.close()
# Out:
# Number of identified cointegrations using the ECM Library by asset:
# Asset: JPY
# Test: AUD , ADF Lags: 0 , Result: No_Cointegration
# Test: NZD , ADF Lags: 0 , Result: No_Cointegration
# Test: EUR , ADF Lags: 0 , Result: No_Cointegration
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: No_Cointegration
# Test: CHF , ADF Lags: 0 , Result: No_Cointegration
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: No_Cointegration
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: SGD , ADF Lags: 0 , Result: No_Cointegration
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result
ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test: IDR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 1 , Result: No_Cointegration
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: No_Cointegration
# Test: NZD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 2 , Result: No_Cointegration
# Test: CAD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 2 , Result: No_Cointegration
# Test: TWD , ADF Lags: 2 , Result: No_Cointegration
# Test: CNY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 2 , Result: No_Cointegration
# Test: RUB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 2 , Result: No_Cointegration
# Test: PHP , ADF Lags: 2 , Result: No_Cointegration
# Test: SGD , ADF Lags: 2 , Result: No_Cointegration
# Test: THB , ADF Lags: 2 , Result: No_Cointegration
# Test: KRW , ADF Lags: 2 , Result: No_Cointegration
# Test: IDR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 2 , Result: No_Cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for AUD : 27 out of total 60
# Asset: NZD
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 0 , Result: No_Cointegration
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: SGD , ADF Lags: 0 , Result: No_Cointegration
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test: IDR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 0 , Result: No_Cointegration
# Test: KHR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: No_Cointegration
# Test: AUD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 1 , Result: No_Cointegration
# Test: GBP , ADF Lags: 1 , Result: No_Cointegration
# Test: CAD , ADF Lags: 1 , Result: No_Cointegration
# Test: CHF , ADF Lags: 1 , Result: No_Cointegration
# Test: TWD , ADF Lags: 1 , Result: No_Cointegration
# Test: CNY , ADF Lags: 1 , Result: No_Cointegration
# Test: INR , ADF Lags: 1 , Result: No_Cointegration
# Test: RUB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 1 , Result: No_Cointegration
# Test: PHP , ADF Lags: 1 , Result: No_Cointegration
# Test: SGD , ADF Lags: 1 , Result: No_Cointegration
# Test: THB , ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test: IDR , ADF Lags: 1 , Result: No_Cointegration
# Test: MYR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 1 , Result: No_Cointegration
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: No_Cointegration
# Test: AUD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 2 , Result: No_Cointegration
# Test: GBP , ADF Lags: 2 , Result: No_Cointegration
# Test: CAD , ADF Lags: 2 , Result: No_Cointegration
# Test: CHF , ADF Lags: 2 , Result: No_Cointegration
# Test: TWD , ADF Lags: 2 , Result: No_Cointegration
# Test: CNY , ADF Lags: 2 , Result: No_Cointegration
# Test: INR , ADF Lags: 2 , Result: No_Cointegration
# Test: RUB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 2 , Result: No_Cointegration
# Test: PHP , ADF Lags: 2 , Result: No_Cointegration
# Test: SGD , ADF Lags: 2 , Result: No_Cointegration
# Test: THB , ADF Lags: 2 , Result: No_Cointegration
# Test: KRW , ADF Lags: 2 , Result: No_Cointegration
# Test: IDR , ADF Lags: 2 , Result: No_Cointegration
# Test: MYR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 2 , Result: No_Cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for NZD : 19 out of total 60
# Asset: EUR
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: No_Cointegration
# Test: NZD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 0 , Result: No_Cointegration
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: No_Cointegration
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: SGD , ADF Lags: 0 , Result: Cointegration_Identified
# Test
cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for CAD : 28 out of total 60
# Asset: CHF
# Test: JPY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 0 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: KHR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 1 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 1 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 2 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 2 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for CHF : 60 out of total 60
# Asset: TWD
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: No_Cointegration
# Test: NZD , ADF Lags: 0 , Result: No_Cointegration
# Test: EUR , ADF Lags: 0 , Result: No_Cointegration
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: No_Cointegration
# Test: CHF , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: No_Cointegration
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: SGD , ADF Lags: 0 , Result: No_Cointegration
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test: IDR , ADF Lags: 0 , Result: No_Cointegration
# Test: MYR , ADF Lags: 0 , Result: No_Cointegration
# Test: VND , ADF Lags: 0 , Result: No_Cointegration
# Test: TRY , ADF Lags: 0 , Result: No_Cointegration
# Test: KHR , ADF Lags: 0 , Result: No_Cointegration
# Test: JPY , ADF Lags: 1 , Result: No_Cointegration
# Test: AUD , ADF Lags: 1 , Result: No_Cointegration
# Test: NZD , ADF Lags: 1 , Result: No_Cointegration
# Test: EUR , ADF Lags: 1 , Result: No_Cointegration
# Test: GBP , ADF Lags: 1 , Result: No_Cointegration
# Test: CAD , ADF Lags: 1 , Result: No_Cointegration
# Test: CHF , ADF Lags: 1 , Result: No_Cointegration
# Test: CNY , ADF Lags: 1 , Result: No_Cointegration
# Test: INR , ADF Lags: 1 , Result: No_Cointegration
# Test: RUB , ADF Lags: 1 , Result: No_Cointegration
# Test: HKD , ADF Lags: 1 , Result: No_Cointegration
# Test: PHP , ADF Lags: 1 , Result: No_Cointegration
# Test: SGD , ADF Lags: 1 , Result: No_Cointegration
# Test: THB , ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test
cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for PHP : 7 out of total 60
# Asset: SGD
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: No_Cointegration
# Test: NZD , ADF Lags: 0 , Result: No_Cointegration
# Test: EUR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test: IDR , ADF Lags: 0 , Result: No_Cointegration
# Test: MYR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 0 , Result: No_Cointegration
# Test: KHR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: No_Cointegration
# Test: AUD , ADF Lags: 1 , Result: No_Cointegration
# Test: NZD , ADF Lags: 1 , Result: No_Cointegration
# Test: EUR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 1 , Result: No_Cointegration
# Test: CAD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 1 , Result: No_Cointegration
# Test: CNY , ADF Lags: 1 , Result: No_Cointegration
# Test: INR , ADF Lags: 1 , Result: No_Cointegration
# Test: RUB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 1 , Result: No_Cointegration
# Test: PHP , ADF Lags: 1 , Result: No_Cointegration
# Test: THB , ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test: IDR , ADF Lags: 1 , Result: No_Cointegration
# Test: MYR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 1 , Result: No_Cointegration
# Test: TRY , ADF Lags: 1 , Result: No_Cointegration
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: No_Cointegration
# Test: AUD , ADF Lags: 2 , Result: No_Cointegration
# Test: NZD , ADF Lags: 2 , Result: No_Cointegration
# Test: EUR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 2 , Result: No_Cointegration
# Test: CAD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 2 , Result: No_Cointegration
# Test: CNY , ADF Lags: 2 , Result: No_Cointegration
# Test: INR , ADF Lags: 2 , Result: No_Cointegration
# Test: RUB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 2 , Result: No_Cointegration
# Test: PHP , ADF Lags: 2 , Result: No_Cointegration
# Test: THB , ADF Lags: 2 , Result: No_Cointegration
# Test: KRW , ADF Lags: 2 , Result: No_Cointegration
# Test: IDR , ADF Lags: 2 , Result: No_Cointegration
# Test: MYR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 2 , Result: No_Cointegration
# Test: TRY , ADF Lags: 2 , Result: No_Cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for SGD : 20 out of total 60
# Asset: THB
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: No_Cointegration
# Test: NZD , ADF Lags: 0 , Result: No_Cointegration
# Test: EUR , ADF Lags: 0 , Result: No_Cointegration
# Test: GBP , ADF Lags: 0 , Result: No_Cointegration
# Test: CAD , ADF Lags: 0 , Result: No_Cointegration
# Test: CHF , ADF Lags: 0 , Result: No_Cointegration
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: No_Cointegration
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: No_Cointegration
# Test: SGD , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test
, ADF Lags: 0 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test: IDR , ADF Lags: 0 , Result: No_Cointegration
# Test: VND , ADF Lags: 0 , Result: No_Cointegration
# Test: TRY , ADF Lags: 0 , Result: No_Cointegration
# Test: KHR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: No_Cointegration
# Test: AUD , ADF Lags: 1 , Result: No_Cointegration
# Test: NZD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 1 , Result: No_Cointegration
# Test: GBP , ADF Lags: 1 , Result: No_Cointegration
# Test: CAD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 1 , Result: No_Cointegration
# Test: TWD , ADF Lags: 1 , Result: No_Cointegration
# Test: CNY , ADF Lags: 1 , Result: No_Cointegration
# Test: INR , ADF Lags: 1 , Result: No_Cointegration
# Test: RUB , ADF Lags: 1 , Result: No_Cointegration
# Test: HKD , ADF Lags: 1 , Result: No_Cointegration
# Test: PHP , ADF Lags: 1 , Result: No_Cointegration
# Test: SGD , ADF Lags: 1 , Result: No_Cointegration
# Test: THB , ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test: IDR , ADF Lags: 1 , Result: No_Cointegration
# Test: VND , ADF Lags: 1 , Result: No_Cointegration
# Test: TRY , ADF Lags: 1 , Result: No_Cointegration
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: No_Cointegration
# Test: AUD , ADF Lags: 2 , Result: No_Cointegration
# Test: NZD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 2 , Result: No_Cointegration
# Test: GBP , ADF Lags: 2 , Result: No_Cointegration
# Test: CAD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 2 , Result: No_Cointegration
# Test: TWD , ADF Lags: 2 , Result: No_Cointegration
# Test: CNY , ADF Lags: 2 , Result: No_Cointegration
# Test: INR , ADF Lags: 2 , Result: No_Cointegration
# Test: RUB , ADF Lags: 2 , Result: No_Cointegration
# Test: HKD , ADF Lags: 2 , Result: No_Cointegration
# Test: PHP , ADF Lags: 2 , Result: No_Cointegration
# Test: SGD , ADF Lags: 2 , Result: No_Cointegration
# Test: THB , ADF Lags: 2 , Result: No_Cointegration
# Test: KRW , ADF Lags: 2 , Result: No_Cointegration
# Test: IDR , ADF Lags: 2 , Result: No_Cointegration
# Test: VND , ADF Lags: 2 , Result: No_Cointegration
# Test: TRY , ADF Lags: 2 , Result: No_Cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for MYR : 12 out of total 60
# Asset: VND
# Test: JPY , ADF Lags: 0 , Result: No_Cointegration
# Test: AUD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 0 , Result: No_Cointegration
# Test: GBP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 0 , Result: No_Cointegration
# Test: CHF , ADF Lags: 0 , Result: No_Cointegration
# Test: TWD , ADF Lags: 0 , Result: No_Cointegration
# Test: CNY , ADF Lags: 0 , Result: No_Cointegration
# Test: INR , ADF Lags: 0 , Result: No_Cointegration
# Test: RUB , ADF Lags: 0 , Result: No_Cointegration
# Test: HKD , ADF Lags: 0 , Result: No_Cointegration
# Test: PHP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 0 , Result: No_Cointegration
# Test: THB , ADF Lags: 0 , Result: No_Cointegration
# Test: KRW , ADF Lags: 0 , Result: No_Cointegration
# Test: IDR , ADF Lags: 0 , Result: No_Cointegration
# Test: MYR , ADF Lags: 0 , Result: No_Cointegration
# Test: TRY , ADF Lags: 0 , Result: No_Cointegration
# Test: KHR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: No_Cointegration
# Test: AUD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 1 , Result: No_Cointegration
# Test: GBP , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 1 , Result: No_Cointegration
# Test: CHF , ADF Lags: 1 , Result: No_Cointegration
# Test
, ADF Lags: 1 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 1 , Result: No_Cointegration
# Test: HKD , ADF Lags: 1 , Result: No_Cointegration
# Test: PHP , ADF Lags: 1 , Result: No_Cointegration
# Test: SGD , ADF Lags: 1 , Result: No_Cointegration
# Test: THB , ADF Lags: 1 , Result: No_Cointegration
# Test: KRW , ADF Lags: 1 , Result: No_Cointegration
# Test: IDR , ADF Lags: 1 , Result: No_Cointegration
# Test: MYR , ADF Lags: 1 , Result: No_Cointegration
# Test: VND , ADF Lags: 1 , Result: No_Cointegration
# Test: KHR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: No_Cointegration
# Test: AUD , ADF Lags: 2 , Result: No_Cointegration
# Test: NZD , ADF Lags: 2 , Result: No_Cointegration
# Test: EUR , ADF Lags: 2 , Result: No_Cointegration
# Test: GBP , ADF Lags: 2 , Result: No_Cointegration
# Test: CAD , ADF Lags: 2 , Result: No_Cointegration
# Test: CHF , ADF Lags: 2 , Result: No_Cointegration
# Test: TWD , ADF Lags: 2 , Result: No_Cointegration
# Test: CNY , ADF Lags: 2 , Result: No_Cointegration
# Test: INR , ADF Lags: 2 , Result: No_Cointegration
# Test: RUB , ADF Lags: 2 , Result: No_Cointegration
# Test: HKD , ADF Lags: 2 , Result: No_Cointegration
# Test: PHP , ADF Lags: 2 , Result: No_Cointegration
# Test: SGD , ADF Lags: 2 , Result: No_Cointegration
# Test: THB , ADF Lags: 2 , Result: No_Cointegration
# Test: KRW , ADF Lags: 2 , Result: No_Cointegration
# Test: IDR , ADF Lags: 2 , Result: No_Cointegration
# Test: MYR , ADF Lags: 2 , Result: No_Cointegration
# Test: VND , ADF Lags: 2 , Result: No_Cointegration
# Test: KHR , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for TRY : 5 out of total 60
# Asset: KHR
# Test: JPY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 0 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 0 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 0 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 0 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 0 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 0 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 0 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 1 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 1 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 1 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 1 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 1 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 1 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 1 , Result: Cointegration_Identified
# Test: JPY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: AUD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: NZD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: EUR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: GBP , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CAD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CHF , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TWD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: CNY , ADF Lags: 2 , Result: Cointegration_Identified
# Test: INR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: RUB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: HKD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: PHP , ADF Lags: 2 , Result: Cointegration_Identified
# Test: SGD , ADF Lags: 2 , Result: Cointegration_Identified
# Test: THB , ADF Lags: 2 , Result: Cointegration_Identified
# Test: KRW , ADF Lags: 2 , Result: Cointegration_Identified
# Test: IDR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: MYR , ADF Lags: 2 , Result: Cointegration_Identified
# Test: VND , ADF Lags: 2 , Result: Cointegration_Identified
# Test: TRY , ADF Lags: 2 , Result: Cointegration_Identified
# Total cointegration identified for KHR : 60 out of total 60
#
#  Total number of regressions conducted: 1260
# Total number of identified cointegrations using only ECM Library: 336
# Total number of identified cointegrations using both ECM Library and own code: 0

# %%
################################## Engle-Granger ECM ####################################################

import pandas as pd
import sqlite3
from statsmodels.tsa.stattools import coint
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

# Perform cointegration test with up to 2 lags
results = []
pairs = []
ols_results = []  # List to store OLS regression results
ecm_results = []  # List to store ECM results

# Iterate over all pairs of columns in df_transformed
for i in range(len(df_data.columns)):
    for j in range(i + 1, len(df_data.columns)):
        col1 = df_data.iloc[:, i]
        col2 = df_data.iloc[:, j]

        # Perform cointegration test with up to 2 lags
        result = coint(col1, col2, maxlag=2)
        score, pvalue = result[:2]

        # Store the results and pairs
        results.append([col1.name, col2.name, score, pvalue])
        pairs.append((col1.name, col2.name))

        # Estimate the OLS regression model
        model = OLS(col1, sm.add_constant(col2)).fit()
        ols_results.append([col1.name, col2.name, model.rsquared, model.params[1], model.pvalues[1]])

        # Estimate the ECM
        error = col1 - model.params[1] * col2
        ecm_model = OLS(error, sm.add_constant(col1)).fit()
        ecm_coefficient = ecm_model.params[1]
        ecm_results.append([col1.name, col2.name, ecm_coefficient])

# Create a DataFrame for the cointegration test results
columns = ['Column_1', 'Column_2', 'Cointegration_Score', 'P_value']
results_df = pd.DataFrame(results, columns=columns)

# Create a DataFrame for the OLS regression results
ols_columns = ['Column_1', 'Column_2', 'R_squared', 'Coefficient', 'P_value']
ols_results_df = pd.DataFrame(ols_results, columns=ols_columns)

# Create a DataFrame for the ECM results
ecm_columns = ['Column_1', 'Column_2', 'ECM_Coefficient']
ecm_results_df = pd.DataFrame(ecm_results, columns=ecm_columns)

# Establish a connection to the SQL database
connection = sqlite3.connect('Currencies_Database_Test.db')

# Export the results to the database table 'Engle_Granger_ECM_Results'
results_df.to_sql('Engle_Granger_Cointegration_Test', connection, if_exists='replace', index=False)
ols_results_df.to_sql('Engle_Granger_OLS_Results', connection, if_exists='replace', index=False)
ecm_results_df.to_sql('Engle_Granger_ECM_Results', connection, if_exists='replace', index=False)

# Close the database connection
connection.close()

print(results_df)
print(ols_results_df)
print(ecm_results_df)
# Out:
#     Column_1 Column_2  Cointegration_Score   P_value
# 0        JPY      AUD            -2.243864  0.401872
# 1        JPY      NZD            -2.848652  0.150695
# 2        JPY      EUR            -2.809011  0.162834
# 3        JPY      GBP            -2.416372  0.317140
# 4        JPY      CAD            -2.005374  0.525783
# ..       ...      ...                  ...       ...
# 205      MYR      TRY            -1.893901  0.583097
# 206      MYR      KHR            -3.341109  0.049325
# 207      VND      TRY            -2.320338  0.363449
# 208      VND      KHR            -3.318662  0.052222
# 209      TRY      KHR            -3.449564  0.037136
#
# [210 rows x 4 columns]
#     Column_1 Column_2  R_squared   Coefficient        P_value
# 0        JPY      AUD   0.419431      0.005458  3.334943e-320
# 1        JPY      NZD   0.429625      0.007421   0.000000e+00
# 2        JPY      EUR   0.547590      0.006085   0.000000e+00
# 3        JPY      GBP   0.202514      0.002460  1.787188e-134
# 4        JPY      CAD   0.341593      0.006216  1.297602e-246
# ..       ...      ...        ...           ...            ...
# 205      MYR      TRY   0.709634      0.173520   0.000000e+00
# 206      MYR      KHR   0.183676   5538.042552  8.343117e-121
# 207      VND      TRY   0.865718      0.000011   0.000000e+00
# 208      VND      KHR   0.199880      0.331692  1.522047e-132
# 209      TRY      KHR   0.232426  30244.160660  7.495663e-157
#
# [210 rows x 5 columns]
#     Column_1 Column_2  ECM_Coefficient
# 0        JPY      AUD         0.580569
# 1        JPY      NZD         0.570375
# 2        JPY      EUR         0.452410
# 3        JPY      GBP         0.797486
# 4        JPY      CAD         0.658407
# ..       ...      ...              ...
# 205      MYR      TRY         0.290366
# 206      MYR      KHR         0.816324
# 207      VND      TRY         0.134282
# 208      VND      KHR         0.800120
# 209      TRY      KHR         0.767574
#
# [210 rows x 3 columns]

# %%
import pandas as pd
import sqlite3
from statsmodels.tsa.stattools import coint
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

# Perform cointegration test with up to 2 lags
results = []
pairs = []
ols_results = []  # List to store OLS regression results
ecm_results = []  # List to store ECM results

# Iterate over all pairs of columns in df_transformed
for i in range(len(df_data.columns)):
    for j in range(i + 1, len(df_data.columns)):
        col1 = df_data.iloc[:, i]
        col2 = df_data.iloc[:, j]

        # Perform cointegration test with up to 2 lags
        result = coint(col1, col2, maxlag=2)
        score, pvalue = result[:2]

        # Store the results and pairs
        results.append([col1.name, col2.name, score, pvalue])
        pairs.append((col1.name, col2.name))

        # Estimate the OLS regression model
        model = OLS(col1, sm.add_constant(col2)).fit()
        ols_results.append([col1.name, col2.name, model.rsquared, model.params[1], model.pvalues[1]])

        # Estimate the ECM
        error = col1 - model.params[1] * col2
        ecm_model = OLS(error, sm.add_constant(col1)).fit()
        ecm_coefficient = ecm_model.params[1]
        ecm_results.append([col1.name, col2.name, ecm_coefficient])

# Create a DataFrame for the cointegration test results
columns = ['Column_1', 'Column_2', 'Cointegration_Score', 'P_value']
results_df = pd.DataFrame(results, columns=columns)

# Create a DataFrame for the OLS regression results
ols_columns = ['Column_1', 'Column_2', 'R_squared', 'Coefficient', 'P_value']
ols_results_df = pd.DataFrame(ols_results, columns=ols_columns)

# Create a DataFrame for the ECM results
ecm_columns = ['Column_1', 'Column_2', 'ECM_Coefficient']
ecm_results_df = pd.DataFrame(ecm_results, columns=ecm_columns)

# Establish a connection to the SQL database
connection = sqlite3.connect('Currencies_Database_Test.db')

# Export the results to the database table 'Engle_Granger_ECM_Results'
results_df.to_sql('Engle_Granger_Cointegration_Test', connection, if_exists='replace', index=False)
ols_results_df.to_sql('Engle_Granger_OLS_Results', connection, if_exists='replace', index=False)
ecm_results_df.to_sql('Engle_Granger_ECM_Results', connection, if_exists='replace', index=False)

# Close the database connection
connection.close()

print(results_df)
print(ols_results_df)
print(ecm_results_df)
# Out:
#     Column_1 Column_2  Cointegration_Score   P_value
# 0        JPY      AUD            -2.243864  0.401872
# 1        JPY      NZD            -2.848652  0.150695
# 2        JPY      EUR            -2.809011  0.162834
# 3        JPY      GBP            -2.416372  0.317140
# 4        JPY      CAD            -2.005374  0.525783
# ..       ...      ...                  ...       ...
# 205      MYR      TRY            -1.893901  0.583097
# 206      MYR      KHR            -3.341109  0.049325
# 207      VND      TRY            -2.320338  0.363449
# 208      VND      KHR            -3.318662  0.052222
# 209      TRY      KHR            -3.449564  0.037136
#
# [210 rows x 4 columns]
#     Column_1 Column_2  R_squared   Coefficient        P_value
# 0        JPY      AUD   0.419431      0.005458  3.334943e-320
# 1        JPY      NZD   0.429625      0.007421   0.000000e+00
# 2        JPY      EUR   0.547590      0.006085   0.000000e+00
# 3        JPY      GBP   0.202514      0.002460  1.787188e-134
# 4        JPY      CAD   0.341593      0.006216  1.297602e-246
# ..       ...      ...        ...           ...            ...
# 205      MYR      TRY   0.709634      0.173520   0.000000e+00
# 206      MYR      KHR   0.183676   5538.042552  8.343117e-121
# 207      VND      TRY   0.865718      0.000011   0.000000e+00
# 208      VND      KHR   0.199880      0.331692  1.522047e-132
# 209      TRY      KHR   0.232426  30244.160660  7.495663e-157
#
# [210 rows x 5 columns]
#     Column_1 Column_2  ECM_Coefficient
# 0        JPY      AUD         0.580569
# 1        JPY      NZD         0.570375
# 2        JPY      EUR         0.452410
# 3        JPY      GBP         0.797486
# 4        JPY      CAD         0.658407
# ..       ...      ...              ...
# 205      MYR      TRY         0.290366
# 206      MYR      KHR         0.816324
# 207      VND      TRY         0.134282
# 208      VND      KHR         0.800120
# 209      TRY      KHR         0.767574
#
# [210 rows x 3 columns]

# %%
############################################## CAUSALITY TEST ##########################################################

# %%
from statsmodels.tsa.stattools import grangercausalitytests
import pandas as pd

# Initialize an empty list to store the results
results = []

# Loop through each pair of columns in the DataFrame
for i, col1 in enumerate(df_data.columns):
    for j, col2 in enumerate(df_data.columns):
        if i == j:
            continue
        # Run the Granger causality test
        result = grangercausalitytests(df_data[[col1, col2]], maxlag=2, verbose=False)
        
        # Extract the test results for the maximum lag order
        maxlag_result = result[2][0]
        
        # Check if any test result is statistically significant (p-value < 0.05)
        significant_results = [res for res in maxlag_result.values() if res[1] < 0.05]
        
        if significant_results:
            # Get the first statistically significant test result
            test_result = significant_results[0]
            
            # Print the test results
            print(f"Granger causality test between {col1} and {col2}:")
            print(f"  Lag Order: {test_result[0]}")
            print(f"  P-value: {test_result[1]}")
            
            # Store the results in a dictionary
            results_dict = {
                'currency1': col1,
                'currency2': col2,
                'lag_order': test_result[0],
                'p_value': test_result[1]
            }
            # Append the dictionary to the list of results
            results.append(results_dict)

# Create a new DataFrame from the list of results
granger_results_df = pd.DataFrame(results)

# Export the DataFrame to an Excel file
granger_results_df.to_excel('granger_causality_results.xlsx', index=False)
# Out:
# Granger causality test between JPY and CAD:
#   Lag Order: 4.627427784930575
#   P-value: 0.009857951472792757
# Granger causality test between JPY and KHR:
#   Lag Order: 5.036295562649837
#   P-value: 0.006559247048619197
# Granger causality test between AUD and JPY:
#   Lag Order: 3.5182803617929
#   P-value: 0.02978704672317632
# Granger causality test between AUD and EUR:
#   Lag Order: 3.8556819412803995
#   P-value: 0.021276335477637645
# Granger causality test between NZD and JPY:
#   Lag Order: 3.066143162281982
#   P-value: 0.046763621719635697
# Granger causality test between EUR and CAD:
#   Lag Order: 6.505833511137768
#   P-value: 0.0015183484388736213
# Granger causality test between EUR and RUB:
#   Lag Order: 4.601305893863978
#   P-value: 0.010117947892880364
# Granger causality test between GBP and CAD:
#   Lag Order: 3.810362669862723
#   P-value: 0.022259876270524524
# Granger causality test between CAD and EUR:
#   Lag Order: 5.979500614601682
#   P-value: 0.002563880067640923
# Granger causality test between CHF and CAD:
#   Lag Order: 7.688601937039782
#   P-value: 0.00046816709241691426
# Granger causality test between CHF and SGD:
#   Lag Order: 4.386482523052153
#   P-value: 0.012533663026010897
# Granger causality test between TWD and JPY:
#   Lag Order: 12.98246310209913
#   P-value: 2.4482466643248473e-06
# Granger causality test between TWD and EUR:
#   Lag Order: 4.200454564466204
#   P-value: 0.015087301405200482
# Granger causality test between TWD and GBP:
#   Lag Order: 4.3259246539252665
#   P-value: 0.013313522070780686
# Granger causality test between TWD and CHF:
#   Lag Order: 9.99863995154088
#   P-value: 4.717637024438367e-05
# Granger causality test between TWD and CNY:
#   Lag Order: 3.464298942667173
#   P-value: 0.03143478647009995
# Granger causality test between TWD and SGD:
#   Lag Order: 16.19282710066767
#   P-value: 1.0223207241992819e-07
# Granger causality test between TWD and THB:
#   Lag Order: 3.010597259090485
#   P-value: 0.04942844927609413
# Granger causality test between CNY and JPY:
#   Lag Order: 5.982174986367132
#   P-value: 0.0025570627676869784
# Granger causality test between CNY and AUD:
#   Lag Order: 15.604188744154575
#   P-value: 1.829109715982288e-07
# Granger causality test between CNY and NZD:
#   Lag Order: 13.016494412159146
#   P-value: 2.367103218159243e-06
# Granger causality test between CNY and EUR:
#   Lag Order: 20.866403701956525
#   P-value: 1.0173951611734793e-09
# Granger causality test between CNY and GBP:
#   Lag Order: 11.862732171146682
#   P-value: 7.424938797886287e-06
# Granger causality test between CNY and CAD:
#   Lag Order: 18.14567645729324
#   P-value: 1.486541365949211e-08
# Granger causality test between CNY and CHF:
#   Lag Order: 8.463334040513713
#   P-value: 0.0002167451717828388
# Granger causality test between CNY and TWD:
#   Lag Order: 18.606887871135054
#   P-value: 9.431443456821328e-09
# Granger causality test between CNY and RUB:
#   Lag Order: 3.030264130554864
#   P-value: 0.04846798121248162
# Granger causality test between CNY and HKD:
#   Lag Order: 5.422107223700894
#   P-value: 0.004466298530424847
# Granger causality test between CNY and PHP:
#   Lag Order: 7.844112026652121
#   P-value: 0.0004010992754597207
# Granger causality test between CNY and SGD:
#   Lag Order: 24.925972536247226
#   P-value: 1.8792423388457425e-11
# Granger causality test between CNY and THB:
#   Lag Order: 10.351786342822331
#   P-value: 3.322827766044697e-05
# Granger causality test between CNY and KRW:
#   Lag Order: 17.56693483950797
#   P-value: 2.631628143478486e-08
# Granger causality test between CNY and MYR:
#   Lag Order: 3.160517041212852
#   P-value: 0.0425614918640959
# Granger causality test between CNY and VND:
#   Lag Order: 3.1340872306994756
#   P-value: 0.043698681848042674
# Granger causality test between CNY and TRY:
#   Lag Order: 3.420654213502772
#   P-value: 0.03283346640025841
# Granger causality test between INR and NZD:
#   Lag Order: 3.1978662139292355
#   P-value: 0.04100479034150809
# Granger causality test between INR and CNY:
#   Lag Order: 3.3264193926513417
#   P-value: 0.03606948083866784
# Granger causality test between INR and RUB:
#   Lag Order: 5.036568769821576
#   P-value: 0.006557461951013751
# Granger causality test between INR and SGD:
#   Lag Order: 4.5329526619666485
#   P-value: 0.01083121803473309
# Granger causality test between INR and TRY:
#   Lag Order: 16.14094632089717
#   P-value: 1.076095446723561e-07
# Granger causality test between INR and KHR:
#   Lag Order: 4.872813699359015
#   P-value: 0.0077195572240659595
# Granger causality test between HKD and AUD:
#   Lag Order: 5.209338080976175
#   P-value: 0.005520622413554048
# Granger causality test between HKD and NZD:
#   Lag Order: 4.894866550514169
#   P-value: 0.007551785551344991
# Granger causality test between HKD and CAD:
#   Lag Order: 5.481749648631434
#   P-value: 0.004208720248084801
# Granger causality test between HKD and TWD:
#   Lag Order: 3.9961431285695586
#   P-value: 0.018495796876513246
# Granger causality test between HKD and CNY:
#   Lag Order: 3.473289903013326
#   P-value: 0.03115414564140277
# Granger causality test between HKD and RUB:
#   Lag Order: 3.7809780667227524
#   P-value: 0.022921781295650603
# Granger causality test between HKD and PHP:
#   Lag Order: 4.874919642519578
#   P-value: 0.007703376020806274
# Granger causality test between HKD and SGD:
#   Lag Order: 3.963429923229822
#   P-value: 0.019109012782337592
# Granger causality test between HKD and KRW:
#   Lag Order: 3.244240813565613
#   P-value: 0.039150970657962275
# Granger causality test between HKD and TRY:
#   Lag Order: 3.1811888910898936
#   P-value: 0.04169272784528817
# Granger causality test between PHP and JPY:
#   Lag Order: 9.893923300437109
#   P-value: 5.234415299296639e-05
# Granger causality test between PHP and EUR:
#   Lag Order: 3.7377390737512894
#   P-value: 0.023931748026989278
# Granger causality test between PHP and CHF:
#   Lag Order: 5.276012655835049
#   P-value: 0.005165878652618004
# Granger causality test between PHP and CNY:
#   Lag Order: 8.247755779568628
#   P-value: 0.00026853148128170115
# Granger causality test between PHP and SGD:
#   Lag Order: 4.3383925098973775
#   P-value: 0.01314908840753803
# Granger causality test between PHP and MYR:
#   Lag Order: 3.825486852307912
#   P-value: 0.021926686634168566
# Granger causality test between PHP and TRY:
#   Lag Order: 7.330067102724902
#   P-value: 0.0006687212150587932
# Granger causality test between SGD and CAD:
#   Lag Order: 3.298421516383157
#   P-value: 0.03709106549923365
# Granger causality test between THB and JPY:
#   Lag Order: 5.830038492469547
#   P-value: 0.0029752553388872147
# Granger causality test between THB and CHF:
#   Lag Order: 4.914374763274056
#   P-value: 0.007406416933462175
# Granger causality test between THB and CNY:
#   Lag Order: 8.59203463095518
#   P-value: 0.00019072517288082762
# Granger causality test between THB and SGD:
#   Lag Order: 3.501062233939087
#   P-value: 0.030303005252133086
# Granger causality test between KRW and JPY:
#   Lag Order: 10.229705238986485
#   P-value: 3.7508004483643804e-05
# Granger causality test between KRW and EUR:
#   Lag Order: 4.765566946257797
#   P-value: 0.008590186418729034
# Granger causality test between KRW and TWD:
#   Lag Order: 5.005113946381754
#   P-value: 0.006766211577469899
# Granger causality test between KRW and SGD:
#   Lag Order: 12.402368713498438
#   P-value: 4.34939822273267e-06
# Granger causality test between KRW and TRY:
#   Lag Order: 5.256895598787157
#   P-value: 0.005265192022889008
# Granger causality test between KRW and KHR:
#   Lag Order: 5.168883251150844
#   P-value: 0.005747642604986219
# Granger causality test between IDR and JPY:
#   Lag Order: 20.303905612749514
#   P-value: 1.7704878686773804e-09
# Granger causality test between IDR and AUD:
#   Lag Order: 110.26515036684668
#   P-value: 9.468490996213112e-47
# Granger causality test between IDR and NZD:
#   Lag Order: 81.69516052435957
#   P-value: 3.606918071659306e-35
# Granger causality test between IDR and EUR:
#   Lag Order: 51.48968833804976
#   P-value: 1.1380877292976272e-22
# Granger causality test between IDR and GBP:
#   Lag Order: 40.77600369455845
#   P-value: 3.586129643168239e-18
# Granger causality test between IDR and CAD:
#   Lag Order: 78.85451744857113
#   P-value: 5.263268848860586e-34
# Granger causality test between IDR and CHF:
#   Lag Order: 21.78849147538604
#   P-value: 4.1047788481843505e-10
# Granger causality test between IDR and TWD:
#   Lag Order: 39.21924692794909
#   P-value: 1.6261881606154307e-17
# Granger causality test between IDR and CNY:
#   Lag Order: 8.391812562342706
#   P-value: 0.00023271114683923
# Granger causality test between IDR and INR:
#   Lag Order: 37.491865809264176
#   P-value: 8.720476705127288e-17
# Granger causality test between IDR and RUB:
#   Lag Order: 31.379307101079455
#   P-value: 3.37950731669786e-14
# Granger causality test between IDR and PHP:
#   Lag Order: 17.458484730035533
#   P-value: 2.928989133931045e-08
# Granger causality test between IDR and SGD:
#   Lag Order: 128.53351444615356
#   P-value: 4.896475230164319e-54
# Granger causality test between IDR and THB:
#   Lag Order: 72.77820976742518
#   P-value: 1.6565417952362735e-31
# Granger causality test between IDR and KRW:
#   Lag Order: 54.7129484426685
#   P-value: 5.1233695162624375e-24
# Granger causality test between IDR and VND:
#   Lag Order: 3.6558547419162513
#   P-value: 0.025968014849640206
# Granger causality test between IDR and TRY:
#   Lag Order: 64.23693292596452
#   P-value: 5.60620561319619e-28
# Granger causality test between MYR and JPY:
#   Lag Order: 30.721038070374398
#   P-value: 6.430994029499392e-14
# Granger causality test between MYR and AUD:
#   Lag Order: 147.29823965583913
#   P-value: 1.9909352442529823e-61
# Granger causality test between MYR and NZD:
#   Lag Order: 109.71941604882305
#   P-value: 1.5680308791692574e-46
# Granger causality test between MYR and EUR:
#   Lag Order: 112.21621521257505
#   P-value: 1.5622043768679756e-47
# Granger causality test between MYR and GBP:
#   Lag Order: 72.65390188386083
#   P-value: 1.8638745826509677e-31
# Granger causality test between MYR and CAD:
#   Lag Order: 146.4964427267711
#   P-value: 4.101588379627541e-61
# Granger causality test between MYR and CHF:
#   Lag Order: 62.91111093333593
#   P-value: 1.9881572547075426e-27
# Granger causality test between MYR and TWD:
#   Lag Order: 70.55989073867333
#   P-value: 1.3608686380978466e-30
# Granger causality test between MYR and CNY:
#   Lag Order: 10.991461525613445
#   P-value: 1.7615286056234408e-05
# Granger causality test between MYR and INR:
#   Lag Order: 21.145601351697934
#   P-value: 7.728626568600161e-10
# Granger causality test between MYR and RUB:
#   Lag Order: 45.10435445940626
#   P-value: 5.408356212783013e-20
# Granger causality test between MYR and HKD:
#   Lag Order: 3.7420499114090093
#   P-value: 0.023829089347839276
# Granger causality test between MYR and PHP:
#   Lag Order: 31.378627472218064
#   P-value: 3.381752452556092e-14
# Granger causality test between MYR and SGD:
#   Lag Order: 245.40074290230322
#   P-value: 1.2995791645801336e-98
# Granger causality test between MYR and THB:
#   Lag Order: 68.09202247493215
#   P-value: 1.4223510057556306e-29
# Granger causality test between MYR and KRW:
#   Lag Order: 88.2502675422459
#   P-value: 7.579306754888937e-38
# Granger causality test between MYR and VND:
#   Lag Order: 10.283709139194098
#   P-value: 3.555069202178153e-05
# Granger causality test between MYR and TRY:
#   Lag Order: 103.44368862007305
#   P-value: 5.254677074813601e-44
# Granger causality test between MYR and KHR:
#   Lag Order: 5.067078050547046
#   P-value: 0.006361146578702939
# Granger causality test between VND and JPY:
#   Lag Order: 14.910209456182816
#   P-value: 3.632845079520655e-07
# Granger causality test between VND and AUD:
#   Lag Order: 21.42619454294159
#   P-value: 5.863309784887364e-10
# Granger causality test between VND and NZD:
#   Lag Order: 20.605973888512167
#   P-value: 1.314842539724817e-09
# Granger causality test between VND and EUR:
#   Lag Order: 14.598711913514636
#   P-value: 4.943778488400371e-07
# Granger causality test between VND and GBP:
#   Lag Order: 9.68627323800605
#   P-value: 6.432755655097266e-05
# Granger causality test between VND and CAD:
#   Lag Order: 8.839406917232422
#   P-value: 0.00014916538549490484
# Granger causality test between VND and CHF:
#   Lag Order: 9.724150437185708
#   P-value: 6.195340426768027e-05
# Granger causality test between VND and TWD:
#   Lag Order: 22.99161674094139
#   P-value: 1.2570258490912708e-10
# Granger causality test between VND and CNY:
#   Lag Order: 20.367945593948885
#   P-value: 1.6622465797370163e-09
# Granger causality test between VND and INR:
#   Lag Order: 4.146073597004061
#   P-value: 0.015927799717616594
# Granger causality test between VND and HKD:
#   Lag Order: 7.4621381385946215
#   P-value: 0.0005864100577383477
# Granger causality test between VND and PHP:
#   Lag Order: 15.973112557923356
#   P-value: 1.270220779888768e-07
# Granger causality test between VND and SGD:
#   Lag Order: 24.803553106821752
#   P-value: 2.1192528809363813e-11
# Granger causality test between VND and THB:
#   Lag Order: 23.452108159493907
#   P-value: 7.993800763577341e-11
# Granger causality test between VND and KRW:
#   Lag Order: 19.980378219450355
#   P-value: 2.43513881611288e-09
# Granger causality test between VND and IDR:
#   Lag Order: 16.849463041900812
#   P-value: 5.344142098210667e-08
# Granger causality test between VND and MYR:
#   Lag Order: 16.99242346181925
#   P-value: 4.640484369022803e-08
# Granger causality test between VND and TRY:
#   Lag Order: 4.565915967339258
#   P-value: 0.010481171566754295
# Granger causality test between TRY and JPY:
#   Lag Order: 4.445481043701426
#   P-value: 0.011817870491611612
# Granger causality test between KHR and JPY:
#   Lag Order: 6.264773881105668
#   P-value: 0.0019300435116380197
# Granger causality test between KHR and AUD:
#   Lag Order: 6.762889590428363
#   P-value: 0.0011756606517968882
# Granger causality test between KHR and NZD:
#   Lag Order: 8.03760320347984
#   P-value: 0.0003309127394181823
# Granger causality test between KHR and EUR:
#   Lag Order: 7.191622708551474
#   P-value: 0.0007674454931633747
# Granger causality test between KHR and GBP:
#   Lag Order: 4.734476515622846
#   P-value: 0.008860483493354445
# Granger causality test between KHR and CAD:
#   Lag Order: 3.478116982427425
#   P-value: 0.03100451065946111
# Granger causality test between KHR and CNY:
#   Lag Order: 3.9325578431411934
#   P-value: 0.019706365841924818
# Granger causality test between KHR and INR:
#   Lag Order: 9.094606894501077
#   P-value: 0.00011576331125574486
# Granger causality test between KHR and RUB:
#   Lag Order: 4.790070056983952
#   P-value: 0.008382985845694708
# Granger causality test between KHR and PHP:
#   Lag Order: 5.087761357733009
#   P-value: 0.006231413584334431
# Granger causality test between KHR and SGD:
#   Lag Order: 3.609343029132315
#   P-value: 0.027200949333047446
# Granger causality test between KHR and KRW:
#   Lag Order: 12.113755626888441
#   P-value: 5.789471987628887e-06
# Granger causality test between KHR and IDR:
#   Lag Order: 5.633800514398188
#   P-value: 0.003617322702959774
# Granger causality test between KHR and MYR:
#   Lag Order: 4.854405050326557
#   P-value: 0.007862457811206003
# Granger causality test between KHR and VND:
#   Lag Order: 8.371345087134538
#   P-value: 0.00023749309503809377
# Granger causality test between KHR and TRY:
#   Lag Order: 8.770579973509793
#   P-value: 0.00015972194580997744

# %%
from statsmodels.tsa.stattools import grangercausalitytests
import pandas as pd
import sqlite3

# Establish a connection to your SQLite database
conn = sqlite3.connect('Currencies_Database_Test.db')
cursor = conn.cursor()

# Initialize an empty list to store the results
results = []

# Loop through each pair of columns in the DataFrame
for i, col1 in enumerate(df_data.columns):
    for j, col2 in enumerate(df_data.columns):
        if i == j:
            continue
        
        # Check if either column is constant
        if df_data[col1].nunique() == 1 or df_data[col2].nunique() == 1:
            continue
        
        # Run the Granger causality test
        result = grangercausalitytests(df_data[[col1, col2]], maxlag=2, verbose=False)
        
        # Store the results in a dictionary
        results_dict = {
            'currency1': col1,
            'currency2': col2,
            'lag_order': result[2][0]['params_ftest'][0],
            'p_value': result[2][0]['params_ftest'][1]
        }
        # Append the dictionary to the list of results
        results.append(results_dict)

# Create a new DataFrame from the list of results
granger_results_df = pd.DataFrame(results)

# Create a table in the SQLite database
table_name = 'Causality_Test_Results'
granger_results_df.to_sql(table_name, conn, if_exists='replace', index=False)

# Commit the changes and close the connection
conn.commit()
conn.close()
